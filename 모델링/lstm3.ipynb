# %%
from pykrx import stock
import pandas as pd

# %%
df = stock.get_market_ohlcv_by_date(fromdate="20170101", todate="20220430", ticker="226490")
df
# Out:
#                시가     고가     저가     종가     거래량
# 날짜
# 2017-01-02  18582  18660  18465  18645  124950
# 2017-01-03  18641  18777  18591  18776  139803
# 2017-01-04  18700  18786  18695  18738  140768
# 2017-01-05  18758  18781  18679  18716  139378
# 2017-01-06  18746  18822  18737  18815  133390
# ...           ...    ...    ...    ...     ...
# 2022-04-25  26975  27059  26817  26818  126321
# 2022-04-26  27034  27034  26886  26916   27439
# 2022-04-27  26438  26690  26424  26690   79157
# 2022-04-28  26815  26960  26655  26960   23699
# 2022-04-29  27000  27245  26905  27195   49158
#
# [1309 rows x 5 columns]

# %%
xdata=pd.read_csv('./exchangeinterest.csv', encoding='unicode_escape')

# %%
xdata
# Out:
#                             Date  exchange  kor_interest  us_insterest
# 0      2017. 1. 1 ?¤í 11:58:00  1205.450          1.25          0.75
# 1      2017. 1. 2 ?¤í 11:58:00  1202.930          1.25          0.75
# 2      2017. 1. 3 ?¤í 11:58:00  1206.010          1.25          0.75
# 3      2017. 1. 4 ?¤í 11:58:00  1194.480          1.25          0.75
# 4      2017. 1. 5 ?¤í 11:58:00  1180.630          1.25          0.75
# ...                          ...       ...           ...           ...
# 1939  2022. 4. 25 ?¤í 11:58:00  1250.210          1.50          0.50
# 1940  2022. 4. 26 ?¤í 11:58:00  1260.810          1.50          0.50
# 1941  2022. 4. 27 ?¤í 11:58:00  1266.415          1.50          0.50
# 1942  2022. 4. 28 ?¤í 11:58:00  1272.405          1.50          0.50
# 1943  2022. 4. 29 ?¤í 11:58:00  1263.485          1.50          0.50
#
# [1944 rows x 4 columns]

# %%
xdata['Date']
# Out:
# 0        2017. 1. 1 ?¤í 11:58:00
# 1        2017. 1. 2 ?¤í 11:58:00
# 2        2017. 1. 3 ?¤í 11:58:00
# 3        2017. 1. 4 ?¤í 11:58:00
# 4        2017. 1. 5 ?¤í 11:58:00
#                    ...
# 1939    2022. 4. 25 ?¤í 11:58:00
# 1940    2022. 4. 26 ?¤í 11:58:00
# 1941    2022. 4. 27 ?¤í 11:58:00
# 1942    2022. 4. 28 ?¤í 11:58:00
# 1943    2022. 4. 29 ?¤í 11:58:00
# Name: Date, Length: 1944, dtype: object

# %%
xdata['Date'] = xdata['Date'].str[:11]

# %%
xdata['Date']
# Out:
# 0       2017. 1. 1
# 1       2017. 1. 2
# 2       2017. 1. 3
# 3       2017. 1. 4
# 4       2017. 1. 5
#            ...
# 1939    2022. 4. 25
# 1940    2022. 4. 26
# 1941    2022. 4. 27
# 1942    2022. 4. 28
# 1943    2022. 4. 29
# Name: Date, Length: 1944, dtype: object

# %%
xdata
# Out:
#              Date  exchange  kor_interest  us_insterest
# 0     2017. 1. 1   1205.450          1.25          0.75
# 1     2017. 1. 2   1202.930          1.25          0.75
# 2     2017. 1. 3   1206.010          1.25          0.75
# 3     2017. 1. 4   1194.480          1.25          0.75
# 4     2017. 1. 5   1180.630          1.25          0.75
# ...           ...       ...           ...           ...
# 1939  2022. 4. 25  1250.210          1.50          0.50
# 1940  2022. 4. 26  1260.810          1.50          0.50
# 1941  2022. 4. 27  1266.415          1.50          0.50
# 1942  2022. 4. 28  1272.405          1.50          0.50
# 1943  2022. 4. 29  1263.485          1.50          0.50
#
# [1944 rows x 4 columns]

# %%
xdata.to_csv("./exkorus.csv",encoding='utf-8-sig')

# %%
print(xdata.isnull().sum())
# Out:
# Date            0
# exchange        0
# kor_interest    0
# us_insterest    0
# dtype: int64

# %%
a=pd.read_csv('./exkorus1.csv')
a
# Out:
#             Date  exchange  kor_interest  us_insterest
# 0     2017-01-01  1205.450          1.25          0.75
# 1     2017-01-02  1202.930          1.25          0.75
# 2     2017-01-03  1206.010          1.25          0.75
# 3     2017-01-04  1194.480          1.25          0.75
# 4     2017-01-05  1180.630          1.25          0.75
# ...          ...       ...           ...           ...
# 1940  2022-04-25  1250.210          1.50          0.50
# 1941  2022-04-26  1260.810          1.50          0.50
# 1942  2022-04-27  1266.415          1.50          0.50
# 1943  2022-04-28  1272.405          1.50          0.50
# 1944  2022-04-29  1263.485          1.50          0.50
#
# [1945 rows x 4 columns]

# %%
b=pd.read_csv('./kospi.csv')
b
# Out:
#               날짜     시가     고가     저가     종가     거래량
# 0     2017-01-02  18582  18660  18465  18645  124950
# 1     2017-01-03  18641  18777  18591  18776  139803
# 2     2017-01-04  18700  18786  18695  18738  140768
# 3     2017-01-05  18758  18781  18679  18716  139378
# 4     2017-01-06  18746  18822  18737  18815  133390
# ...          ...    ...    ...    ...    ...     ...
# 1304  2022-04-25  26975  27059  26817  26818  126321
# 1305  2022-04-26  27034  27034  26886  26916   27439
# 1306  2022-04-27  26438  26690  26424  26690   79157
# 1307  2022-04-28  26815  26960  26655  26960   23699
# 1308  2022-04-29  27000  27245  26905  27195   49158
#
# [1309 rows x 6 columns]

# %%
b.rename(columns={'날짜':'Date'}, inplace=True)

# %%
b
# Out:
#             Date     시가     고가     저가     종가     거래량
# 0     2017-01-02  18582  18660  18465  18645  124950
# 1     2017-01-03  18641  18777  18591  18776  139803
# 2     2017-01-04  18700  18786  18695  18738  140768
# 3     2017-01-05  18758  18781  18679  18716  139378
# 4     2017-01-06  18746  18822  18737  18815  133390
# ...          ...    ...    ...    ...    ...     ...
# 1304  2022-04-25  26975  27059  26817  26818  126321
# 1305  2022-04-26  27034  27034  26886  26916   27439
# 1306  2022-04-27  26438  26690  26424  26690   79157
# 1307  2022-04-28  26815  26960  26655  26960   23699
# 1308  2022-04-29  27000  27245  26905  27195   49158
#
# [1309 rows x 6 columns]

# %%
merge = pd.merge(b, a, on='Date', how='left')
merge
# Out:
#             Date     시가     고가     저가     종가     거래량  exchange  kor_interest  \
# 0     2017-01-02  18582  18660  18465  18645  124950  1202.930          1.25
# 1     2017-01-03  18641  18777  18591  18776  139803  1206.010          1.25
# 2     2017-01-04  18700  18786  18695  18738  140768  1194.480          1.25
# 3     2017-01-05  18758  18781  18679  18716  139378  1180.630          1.25
# 4     2017-01-06  18746  18822  18737  18815  133390  1200.000          1.25
# ...          ...    ...    ...    ...    ...     ...       ...           ...
# 1304  2022-04-25  26975  27059  26817  26818  126321  1250.210          1.50
# 1305  2022-04-26  27034  27034  26886  26916   27439  1260.810          1.50
# 1306  2022-04-27  26438  26690  26424  26690   79157  1266.415          1.50
# 1307  2022-04-28  26815  26960  26655  26960   23699  1272.405          1.50
# 1308  2022-04-29  27000  27245  26905  27195   49158  1263.485          1.50
#
#       us_insterest
# 0             0.75
# ...

# %%
merge2 = merge.iloc[:,[0,4,6,7,8]]
merge2
# Out:
#             Date     종가  exchange  kor_interest  us_insterest
# 0     2017-01-02  18645  1202.930          1.25          0.75
# 1     2017-01-03  18776  1206.010          1.25          0.75
# 2     2017-01-04  18738  1194.480          1.25          0.75
# 3     2017-01-05  18716  1180.630          1.25          0.75
# 4     2017-01-06  18815  1200.000          1.25          0.75
# ...          ...    ...       ...           ...           ...
# 1304  2022-04-25  26818  1250.210          1.50          0.50
# 1305  2022-04-26  26916  1260.810          1.50          0.50
# 1306  2022-04-27  26690  1266.415          1.50          0.50
# 1307  2022-04-28  26960  1272.405          1.50          0.50
# 1308  2022-04-29  27195  1263.485          1.50          0.50
#
# [1309 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# 스케일을 적용할 column을 정의합니다.
scale_cols = ['종가', 'exchange', 'kor_interest', 'us_insterest']
# 스케일 후 columns
scaled = scaler.fit_transform(merge2[scale_cols])
scaled
# Out:
# array([[0.2400673 , 0.68229107, 0.6       , 0.22222222],
#        [0.24717759, 0.6963759 , 0.6       , 0.22222222],
#        [0.24511507, 0.64364925, 0.6       , 0.22222222],
#        ...,
#        [0.67672601, 0.97260775, 0.8       , 0.11111111],
#        [0.69138081, 1.        , 0.8       , 0.11111111],
#        [0.70413591, 0.95920887, 0.8       , 0.11111111]])

# %%
df = pd.DataFrame(scaled, columns=scale_cols)
df
# Out:
#             종가  exchange  kor_interest  us_insterest
# 0     0.240067  0.682291           0.6      0.222222
# 1     0.247178  0.696376           0.6      0.222222
# 2     0.245115  0.643649           0.6      0.222222
# 3     0.243921  0.580313           0.6      0.222222
# 4     0.249294  0.668892           0.6      0.222222
# ...        ...       ...           ...           ...
# 1304  0.683673  0.898502           0.8      0.111111
# 1305  0.688993  0.946976           0.8      0.111111
# 1306  0.676726  0.972608           0.8      0.111111
# 1307  0.691381  1.000000           0.8      0.111111
# 1308  0.704136  0.959209           0.8      0.111111
#
# [1309 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.drop('종가', 1), df['종가'], test_size=0.2, random_state=0, shuffle=False)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18016\162671171.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_train, x_test, y_train, y_test = train_test_split(df.drop('종가', 1), df['종가'], test_size=0.2, random_state=0, shuffle=False)

# %%
x_train.shape, y_train.shape
# Out:
# ((1047, 3), (1047,))

# %%
x_test.shape, y_test.shape
# Out:
# ((262, 3), (262,))

# %%
x_train
# Out:
#       exchange  kor_interest  us_insterest
# 0     0.682291           0.6      0.222222
# 1     0.696376           0.6      0.222222
# 2     0.643649           0.6      0.222222
# 3     0.580313           0.6      0.222222
# 4     0.668892           0.6      0.222222
# ...        ...           ...           ...
# 1042  0.344072           0.0      0.000000
# 1043  0.321847           0.0      0.000000
# 1044  0.291620           0.0      0.000000
# 1045  0.293266           0.0      0.000000
# 1046  0.284029           0.0      0.000000
#
# [1047 rows x 3 columns]

# %%
import tensorflow as tf

def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE=20
BATCH_SIZE=32

# %%
# trian_data는 학습용 데이터셋, test_data는 검증용 데이터셋 입니다.
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, True)
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


model = Sequential([
    # 1차원 feature map 생성
    Conv1D(filters=32, kernel_size=5,
           padding="causal",
           activation="relu",
           input_shape=[WINDOW_SIZE, 1]),
    # LSTM
    LSTM(16, activation='tanh'),
    Dense(16, activation="relu"),
    Dense(1),
])

# %%
# Sequence 학습에 비교적 좋은 퍼포먼스를 내는 Huber()를 사용합니다.
loss = Huber()
optimizer = Adam(0.0005)
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
import os

# earlystopping은 10번 epoch통안 val_loss 개선이 없다면 학습을 멈춥니다.
earlystopping = EarlyStopping(monitor='val_loss', patience=10)
# val_loss 기준 체크포인터도 생성합니다.
filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %%
history = model.fit(train_data, 
                    validation_data=(test_data), 
                    epochs=50, 
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/50
#      30/Unknown - 3s 5ms/step - loss: 0.0643 - mse: 0.1286
# Epoch 1: val_loss improved from inf to 0.12328, saving model to tmp\ckeckpointer.ckpt
# 33/33 [==============================] - 4s 59ms/step - loss: 0.0616 - mse: 0.1232 - val_loss: 0.1233 - val_mse: 0.2466
# Epoch 2/50
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0099 - mse: 0.0197
# Epoch 2: val_loss improved from 0.12328 to 0.01667, saving model to tmp\ckeckpointer.ckpt
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0096 - mse: 0.0192 - val_loss: 0.0167 - val_mse: 0.0333
# Epoch 3/50
# 28/33 [========================>.....] - ETA: 0s - loss: 0.0024 - mse: 0.0049
# Epoch 3: val_loss improved from 0.01667 to 0.01520, saving model to tmp\ckeckpointer.ckpt
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0050 - val_loss: 0.0152 - val_mse: 0.0304
# Epoch 4/50
# 28/33 [========================>.....] - ETA: 0s - loss: 0.0016 - mse: 0.0033
# ...

# %%
model.load_weights(filename)

# %%
pred = model.predict(test_data)

# %%
pred.shape
# Out:
# (242, 1)

# %%
pred
# Out:
# array([[0.92249423],
#        [0.93192524],
#        [0.93486935],
#        [0.9302529 ],
#        [0.9188896 ],
#        [0.91497356],
#        [0.91362816],
#        [0.91723853],
#        [0.91740376],
#        [0.91740394],
#        [0.9153739 ],
#        [0.91600204],
#        [0.91770303],
#        [0.91791016],
#        [0.9193141 ],
#        [0.92257696],
#        [0.92775536],
#        [0.9313294 ],
#        [0.9358885 ],
#        [0.9386619 ],
#        [0.9428831 ],
#        [0.9442855 ],
#        [0.9430949 ],
#        [0.94212145],
#        [0.9439778 ],
#        [0.94713706],
#        [0.9502617 ],
#        [0.953488  ],
#        [0.95525235],
#        [0.95571023],
#        [0.95274746],
#        [0.9528958 ],
#        [0.95568436],
#        [0.9603861 ],
#        [0.9639903 ],
#        [0.9659653 ],
#        [0.96646595],
#        [0.96823114],
#        [0.96754414],
#        [0.96799487],
#        [0.96849245],
#        [0.970972  ],
#        [0.9705753 ],
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 9))
plt.plot(np.asarray(y_test)[20:], label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %%
y_test2 = np.asarray(y_test)[20:]

# %%
y_test2
# Out:
# array([0.96982197, 0.95272471, 0.92656318, 0.90354972, 0.92173252,
#        0.91212549, 0.92867998, 0.92281806, 0.92227529, 0.91825879,
#        0.92786583, 0.93025402, 0.92357794, 0.93508467, 0.94442032,
#        0.95218194, 0.95353886, 0.96634824, 0.96233174, 0.97302432,
#        0.96607686, 0.95408163, 0.95858663, 0.9671624 , 0.96819366,
#        0.97438124, 0.98208858, 0.97758359, 0.97595528, 0.96260313,
#        0.97410986, 0.98344551, 0.9898502 , 0.99440947, 0.99495224,
#        0.99147851, 0.99972861, 0.98719062, 0.99229266, 0.99495224,
#        1.        , 0.98930743, 0.97676943, 0.95804386, 0.97302432,
#        0.98187147, 0.97839774, 0.99468085, 0.98453105, 0.96743378,
#        0.96580547, 0.95457013, 0.97090751, 0.9732957 , 0.96233174,
#        0.96634824, 0.96900782, 0.9671624 , 0.94523448, 0.95674121,
#        0.96900782, 0.99229266, 0.9853452 , 0.98263135, 0.97676943,
#        0.96634824, 0.95619844, 0.94843682, 0.93188233, 0.91559922,
# ...

# %%
pred2 = np.concatenate(tuple(pred))
pred2
# Out:
# array([0.92249423, 0.93192524, 0.93486935, 0.9302529 , 0.9188896 ,
#        0.91497356, 0.91362816, 0.91723853, 0.91740376, 0.91740394,
#        0.9153739 , 0.91600204, 0.91770303, 0.91791016, 0.9193141 ,
#        0.92257696, 0.92775536, 0.9313294 , 0.9358885 , 0.9386619 ,
#        0.9428831 , 0.9442855 , 0.9430949 , 0.94212145, 0.9439778 ,
#        0.94713706, 0.9502617 , 0.953488  , 0.95525235, 0.95571023,
#        0.95274746, 0.9528958 , 0.95568436, 0.9603861 , 0.9639903 ,
#        0.9659653 , 0.96646595, 0.96823114, 0.96754414, 0.96799487,
#        0.96849245, 0.970972  , 0.9705753 , 0.9669983 , 0.9598751 ,
#        0.95784146, 0.95976233, 0.96199715, 0.9651334 , 0.9649435 ,
#        0.9614302 , 0.95670176, 0.95173854, 0.9525498 , 0.95420414,
#        0.95380944, 0.9524047 , 0.9516952 , 0.95202833, 0.94745153,
#        0.94509476, 0.94653505, 0.9545745 , 0.958954  , 0.95992583,
#        0.9577289 , 0.9547321 , 0.950782  , 0.94637316, 0.9402459 ,
# ...

# %%
def accuracy_score(y_test2, pred):
    pred2 = np.concatenate(tuple(pred))
    return (y_test2 == pred2).sum() / float(len(y_test2))

# %%
print(accuracy_score(y_test2, pred))  #정확도를 확인할 수 있는 지표를 뭐로 해야할지?
# Out:
# 0.0
