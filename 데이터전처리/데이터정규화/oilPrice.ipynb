# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
# 그래프 한글, 마이너스 깨짐 방지

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
# ## 닭고기가격, 병아리가격 그래프 시각화

# %%
price_df = pd.read_csv('../pre_data/월별_닭고기가격.csv', header=0, encoding='utf8')
price_df
# Out:
#      Unnamed: 0        date  price
# 0             0  2012-01-31   3202
# 1             1  2012-02-29   3668
# 2             2  2012-03-31   4169
# 3             3  2012-04-30   3399
# 4             4  2012-05-31   3255
# ..          ...         ...    ...
# 115         115  2021-08-31   3505
# 116         116  2021-09-30   3074
# 117         117  2021-10-31   3913
# 118         118  2021-11-30   2985
# 119         119  2021-12-31   3320
#
# [120 rows x 3 columns]

# %%
oil_df = pd.read_csv('../pre_data/월별_원유가격.csv', encoding='utf8')
oil_df
# Out:
#      Unnamed: 0        date       Dubai       Brent         WTI     oil_avg
# 0             0  2012-01-31  109.456667  111.452381  100.289286  107.066111
# 1             1  2012-02-29  116.180952  119.060000  102.370952  112.537302
# 2             2  2012-03-31  122.487273  124.544545  106.205000  117.745606
# 3             3  2012-04-30  117.338500  120.486500  103.346000  113.723667
# 4             4  2012-05-31  107.719348  110.288696   94.546087  104.184710
# ..          ...         ...         ...         ...         ...         ...
# 115         115  2021-08-31   69.518864   70.513636   67.711364   69.247955
# 116         116  2021-09-30   72.628182   74.876364   71.420909   72.975152
# 117         117  2021-10-31   81.610952   83.746190   81.222857   82.193333
# 118         118  2021-11-30   80.317500   80.849545   78.409091   79.858712
# 119         119  2021-12-31   73.303043   74.803913   71.820000   73.308986
#
# [120 rows x 6 columns]

# %%
oil_df.drop(labels='Unnamed: 0',axis=1,inplace=True)

# %%
# 닭고기 가격, 수입량 기본 그래프

plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_df['date']
y1 = price_df['price']
y2 = oil_df['oil_avg']

fig, ax1 = plt.subplots()
ax1.set_title('월별 닭고기, 원유가격 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='blue',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('원유가격')
ax2.plot(x, y2, color='red',label='원유가격')

plt.xticks(['2012-01-31', '2013-01-31', '2014-01-31','2015-01-31','2016-01-31','2017-01-31', '2018-01-31', '2019-01-31', '2020-01-31', '2021-01-31'])
fig.legend()
# plt.legend()
plt.show()

# %% [markdown]
# ### 병아리가격 데이터 범위 쪼개서 그래프 그리기

# %%
# 오일가격 범위 분리
oil_group1 = oil_df.iloc[:23,:]
oil_group2 = oil_df.iloc[24:83,:]
oil_group3 = oil_df.iloc[84:,:]

# %%
# 수입량에 맞춰 닭고기 가격 기간 분리
price_group1 = price_df.iloc[:23,:]
price_group2 = price_df.iloc[24:83,:]
price_group3 = price_df.iloc[84:,:]

# %% [markdown]
# #### 그룹별 시각화 그래프

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group1['date']
y1 = price_group1['price']
y2 = oil_group1['oil_avg']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 원유가격 그룹1 (2012-2013) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('원유가격')
ax2.plot(x, y2, color='blue',label='원유가격')

plt.xticks(['2012-01-31', '2012-04-30', '2012-07-31', '2012-10-31', '2013-01-31', '2013-04-30', '2013-07-31', '2013-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group2['date']
y1 = price_group2['price']
y2 = oil_group2['oil_avg']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 원유가격 그룹2 (2014-2018) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('원유가격')
ax2.plot(x, y2, color='blue',label='원유가격')

plt.xticks(['2014-01-31', '2014-04-30', '2014-07-31', '2014-10-31', '2015-01-31', '2015-04-30', '2015-07-31', '2015-10-31', '2016-01-31', '2016-04-30', '2016-07-31', '2016-10-31',
             '2017-01-31', '2017-04-30', '2017-07-31', '2017-10-31', '2018-01-31', '2018-04-30', '2018-07-31', '2018-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group3['date']
y1 = price_group3['price']
y2 = oil_group3['oil_avg']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 원유가격 그룹3 (2019-2021) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('원유가격')
ax2.plot(x, y2, color='blue',label='원유가격')

plt.xticks(['2019-01-31', '2019-04-30', '2019-07-31', '2019-10-31', '2020-01-31', '2020-04-30', '2020-07-31', '2020-10-31', '2021-01-31', '2021-04-30', '2021-07-31', '2021-10-31'])
fig.legend()
plt.show()

# %% [markdown]
# ## 닭고기 - 수입량 나온 값을 그 값들의 평균을 내서, 평균으로부터의 값들의 거리를 계산
# - 거리를 양수값으로 변경해도 될듯 (절댓값 사용)
# - 그거에 대한 범주화 하기
#
# ### 닭고기 가격에 변동이 되는 이벤트 시점을 찾아보기
# - 물가동향, 금리인상, 복날, 전쟁
#
# ### 22년도 데이터들로 학습 모델에 테스트 해보기

# %% [markdown]
# ## 정규화
# - MinMaxScaler / StandardScaler 두 가지 방법이 있음
# - 두 개 다 돌려보고 정확도가 더 높은 함수를 사용함. 보통 잘 모를때는 StandardScaler 사용함. (해보고 별로면 MinMaxScaler 사용)
#
# - 배열화 처리 먼저 해주기 (numpy 사용)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
# 스케일링 함수
ss = StandardScaler()

# %% [markdown]
# #### 닭고기 가격 정규화 값 컬럼 추가 (배열화 > 스케일링 > 차원축소 > 컬럼추가)

# %%
# 닭고기 가격 데이터 배열화 처리
price_df2 = price_df[['price']].to_numpy()
price_df2
# Out:
# array([[3202],
#        [3668],
#        [4169],
#        [3399],
#        [3255],
#        [3493],
#        [3703],
#        [3745],
#        [3275],
#        [3520],
#        [3519],
#        [3340],
#        [3232],
#        [3935],
#        [4010],
#        [3295],
#        [3535],
#        [3762],
#        [4177],
#        [4015],
#        [3450],
#        [4092],
#        [3684],
#        [3316],
#        [3368],
#        [3391],
#        [3651],
#        [3964],
#        [3017],
#        [3118],
#        [3223],
#        [3249],
#        [3008],
#        [3632],
#        [3638],
#        [3745],
#        [3725],
#        [3802],
#        [3690],
#        [3549],
#        [3106],
#        [3157],
#        [3384],
#        [3192],
#        [2866],
#        [2944],
#        [2895],
#        [3215],
#        [3072],
#        [2938],
#        [3050],
#        [2793],
#        [2898],
#        [3334],
#        [3172],
#        [3579],
#        [3223],
#        [3858],
#        [3158],
#        [2684],
#        [2733],
#        [3926],
#        [3818],
#        [3894],
#        [4456],
#        [3191],
#        [3221],
#        [2811],
#        [2664],
#        [3105],
#        [3063],
#        [2640],
#        [2513],
#        [2877],
#        [3243],
#        [3070],
#        [2977],
#        [2630],
#        [3297],
#        [3819],
#        [3057],
#        [3307],
#        [2938],
#        [3827],
#        [4281],
#        [3384],
#        [3397],
#        [3166],
#        [2841],
#        [2656],
#        [2783],
#        [2808],
#        [2524],
#        [3011],
#        [2500],
#        [2834],
#        [2750],
#        [2913],
#        [2834],
#        [2530],
#        [2457],
#        [2759],
#        [2972],
#        [3060],
#        [3053],
#        [2682],
#        [2931],
#        [3314],
#        [3985],
#        [3382],
#        [3148],
#        [3215],
#        [2923],
#        [2863],
#        [3646],
#        [3505],
#        [3074],
#        [3913],
#        [2985],
#        [3320]], dtype=int64)

# %%
ss.fit(price_df2)
priceScale=ss.transform(price_df2)
priceScale
# Out:
# array([[-0.15938547],
#        [ 0.91251299],
#        [ 2.06491884],
#        [ 0.29375615],
#        [-0.03747428],
#        [ 0.50997601],
#        [ 0.99302038],
#        [ 1.08962926],
#        [ 0.00852995],
#        [ 0.57208172],
#        [ 0.56978151],
#        [ 0.15804368],
#        [-0.09037914],
#        [ 1.5266694 ],
#        [ 1.69918525],
#        [ 0.05453418],
#        [ 0.60658489],
#        [ 1.12873285],
#        [ 2.08332053],
#        [ 1.7106863 ],
#        [ 0.41106693],
#        [ 1.88780257],
#        [ 0.94931637],
#        [ 0.10283861],
#        [ 0.2224496 ],
#        [ 0.27535446],
#        [ 0.8734094 ],
#        [ 1.59337553],
#        [-0.58492456],
#        [-0.35260322],
#        [-0.11108104],
#        [-0.05127554],
#        [-0.60562646],
#        [ 0.82970538],
#        [ 0.84350665],
#        [ 1.08962926],
#        [ 1.04362503],
#        [ 1.2207413 ],
#        [ 0.96311764],
#        [ 0.63878784],
#        [-0.38020576],
#        [-0.26289498],
#        [ 0.25925298],
#        [-0.18238759],
#        [-0.93225647],
#        [-0.75283999],
#        [-0.86555034],
#        [-0.12948273],
#        [-0.45841294],
#        [-0.76664125],
#        [-0.50901759],
#        [-1.10017189],
#        [-0.85864971],
#        [ 0.14424242],
#        [-0.22839181],
#        [ 0.70779418],
#        [-0.11108104],
#        [ 1.34955313],
#        [-0.26059477],
#        [-1.35089492],
#        [-1.23818457],
#        [ 1.5059675 ],
#        [ 1.25754468],
#        [ 1.43236074],
#        [ 2.72507948],
#        [-0.1846878 ],
#        [-0.11568146],
#        [-1.05876809],
#        [-1.39689915],
#        [-0.38250597],
#        [-0.47911484],
#        [-1.45210422],
#        [-1.74423105],
#        [-0.90695414],
#        [-0.06507681],
#        [-0.46301336],
#        [-0.67693301],
#        [-1.47510633],
#        [ 0.0591346 ],
#        [ 1.25984489],
#        [-0.49291611],
#        [ 0.08213671],
#        [-0.76664125],
#        [ 1.27824658],
#        [ 2.32254251],
#        [ 0.25925298],
#        [ 0.28915573],
#        [-0.24219308],
#        [-0.98976175],
#        [-1.41530084],
#        [-1.123174  ],
#        [-1.06566872],
#        [-1.71892873],
#        [-0.59872583],
#        [-1.7741338 ],
#        [-1.00586323],
#        [-1.19908098],
#        [-0.82414654],
#        [-1.00586323],
#        [-1.70512746],
#        [-1.87304289],
#        [-1.17837908],
#        [-0.68843407],
#        [-0.48601548],
#        [-0.50211696],
#        [-1.35549534],
#        [-0.78274273],
#        [ 0.09823819],
#        [ 1.64167997],
#        [ 0.25465256],
#        [-0.28359688],
#        [-0.12948273],
#        [-0.80114442],
#        [-0.9391571 ],
#        [ 0.86190834],
#        [ 0.53757855],
#        [-0.45381252],
#        [ 1.47606475],
#        [-0.65853132],
#        [ 0.11203946]])

# %%
# 2차원 -> 1차원 리스트에 담기
price_list=[]
for i in priceScale :
    price_list.append(i[0])

price_list
# Out:
# [-0.1593854739813105,
#  0.9125129872375594,
#  2.064918843612353,
#  0.2937561501820315,
#  -0.037474275602340325,
#  0.5099760114579408,
#  0.9930203823934831,
#  1.0896292565805914,
#  0.008529950201044646,
#  0.5720817162925106,
#  0.5697815050023413,
#  0.1580436840620458,
#  -0.09037913527623305,
#  1.5266694017127487,
#  1.6991852484754424,
#  0.05453417600442962,
#  0.6065848856450493,
#  1.1287328485134687,
#  2.083320533933707,
#  1.7106863049262886,
#  0.41106692598066313,
#  1.8878025742693207,
#  0.9493163678802673,
#  0.10283861309798384,
#  0.22244960018678478,
#  0.27535445986067747,
#  0.8734093953046821,
#  1.593375529127657,
#  -0.5849245626626215,
#  -0.3526032223555274,
#  -0.11108103688775628,
#  -0.051275543343355816,
#  -0.6056264642741448,
#  0.8297053807914664,
#  0.8435066485324819,
#  1.0896292565805914,
#  1.0436250307772066,
#  1.2207413001202387,
#  0.9631176356212828,
#  0.6387878437074188,
#  -0.3802057578375584,
#  -0.2628949820389267,
#  0.2592529808294928,
#  -0.182387586883003,
#  -0.932256467478178,
#  -0.7528399868449767,
#  -0.8655503400632698,
#  -0.12948272720911028,
#  -0.4584129417033128,
#  -0.7666412545859922,
#  -0.5090175900870363,
#  -1.1001718916605332,
#  -0.858649706192762,
#  0.14424241632103033,
#  -0.22839181268638797,
#  0.7077941824124963,
#  -0.11108103688775628,
#  1.3495531323697165,
#  -0.2605947707487574,
#  -1.3508949222889812,
#  -1.238184569070688,
#  1.5059675001012256,
#  1.2575446807629467,
#  1.4323607388158095,
#  2.7250794838909274,
#  -0.18468779817317224,
#  -0.11568145946809479,
#  -1.0587680884374868,
#  -1.3968991480923663,
#  -0.3825059691277276,
#  -0.47911484331483606,
#  -1.4521042190564282,
#  -1.7442310529079228,
#  -0.9069541432863163,
#  -0.06507681108437131,
#  -0.4630133642836513,
#  -0.6769330142693915,
#  -1.4751063319581208,
#  0.05913459858476812,
#  1.259844892053116,
#  -0.49291611105585154,
#  0.08213671148646061,
#  -0.7666412545859922,
#  1.27824658237447,
#  2.322542508111309,
#  0.2592529808294928,
#  0.289155727601693,
#  -0.24219308042740345,
#  -0.9897617497324093,
#  -1.4153008384137202,
#  -1.1231740045622256,
#  -1.0656687223079944,
#  -1.718928728716061,
#  -0.598725830403637,
#  -1.774133799680123,
#  -1.005863228763594,
#  -1.1990809771378108,
#  -0.8241465368402233,
#  -1.005863228763594,
#  -1.7051274609750455,
#  -1.8730428851574008,
#  -1.1783790755262877,
#  -0.6884340707202377,
#  -0.4860154771853438,
#  -0.5021169562165285,
#  -1.3554953448693199,
#  -0.7827427336171768,
#  0.09823819051764535,
#  1.6416799662212112,
#  0.2546525582491542,
#  -0.28359688365044994,
#  -0.12948272720911028,
#  -0.8011444239385309,
#  -0.9391571013486858,
#  0.8619083388538359,
#  0.5375785469399719,
#  -0.4538125191229743,
#  1.4760647533290252,
#  -0.6585313239480375,
#  0.11203945825866084]

# %%
price_df['price_ss'] = price_list
price_df
# Out:
#      Unnamed: 0        date  price  price_ss
# 0             0  2012-01-31   3202 -0.159385
# 1             1  2012-02-29   3668  0.912513
# 2             2  2012-03-31   4169  2.064919
# 3             3  2012-04-30   3399  0.293756
# 4             4  2012-05-31   3255 -0.037474
# ..          ...         ...    ...       ...
# 115         115  2021-08-31   3505  0.537579
# 116         116  2021-09-30   3074 -0.453813
# 117         117  2021-10-31   3913  1.476065
# 118         118  2021-11-30   2985 -0.658531
# 119         119  2021-12-31   3320  0.112039
#
# [120 rows x 4 columns]

# %%
price_df.drop(labels='Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# #### 원유가격 정규화 값 컬럼 추가 (배열화 > 스케일링 > 차원축소 > 컬럼추가)

# %%
# 원유가격 데이터 배열화 처리
oil_df2 = oil_df[['oil_avg']].to_numpy()

# %%
ss.fit(oil_df2)
oilScale=ss.transform(oil_df2)
oilScale
# Out:
# array([[ 1.55178108],
#        [ 1.7770179 ],
#        [ 1.99143229],
#        [ 1.82585793],
#        [ 1.43316017],
#        [ 0.88644751],
#        [ 1.11978542],
#        [ 1.47351057],
#        [ 1.51959359],
#        [ 1.39747247],
#        [ 1.30948161],
#        [ 1.31226573],
#        [ 1.46825829],
#        [ 1.57254223],
#        [ 1.37145472],
#        [ 1.22223708],
#        [ 1.23722237],
#        [ 1.25146434],
#        [ 1.47393717],
#        [ 1.58695875],
#        [ 1.61099082],
#        [ 1.47541384],
#        [ 1.36053709],
#        [ 1.48123713],
#        [ 1.34215698],
#        [ 1.46023649],
#        [ 1.43378635],
#        [ 1.46339776],
#        [ 1.48986826],
#        [ 1.6045706 ],
#        [ 1.49063697],
#        [ 1.28027297],
#        [ 1.10041161],
#        [ 0.69809734],
#        [ 0.33154605],
#        [-0.3475781 ],
#        [-0.89536634],
#        [-0.58355219],
#        [-0.66732708],
#        [-0.47523924],
#        [-0.27646089],
#        [-0.32458027],
#        [-0.61265229],
#        [-0.94734231],
#        [-0.93808639],
#        [-0.91541915],
#        [-1.06525863],
#        [-1.33061503],
#        [-1.61508322],
#        [-1.58196667],
#        [-1.30530308],
#        [-1.16179383],
#        [-0.95144097],
#        [-0.86505722],
#        [-1.01537699],
#        [-0.99644946],
#        [-0.99206921],
#        [-0.79343359],
#        [-0.97865538],
#        [-0.67175336],
#        [-0.63611055],
#        [-0.6068806 ],
#        [-0.75066284],
#        [-0.69826858],
#        [-0.79245113],
#        [-0.9465445 ],
#        [-0.88851811],
#        [-0.79474817],
#        [-0.67697775],
#        [-0.59443514],
#        [-0.37992912],
#        [-0.33575982],
#        [-0.12572425],
#        [-0.2408269 ],
#        [-0.21792748],
#        [-0.02411214],
#        [ 0.17753361],
#        [ 0.11953732],
#        [ 0.14638549],
#        [ 0.08255534],
#        [ 0.25112477],
#        [ 0.31101271],
#        [-0.27253109],
#        [-0.61313124],
#        [-0.50997568],
#        [-0.33291925],
#        [-0.21926707],
#        [-0.02294245],
#        [-0.10210606],
#        [-0.39382699],
#        [-0.31675134],
#        [-0.47769327],
#        [-0.38214776],
#        [-0.48047087],
#        [-0.3617599 ],
#        [-0.25018212],
#        [-0.31198667],
#        [-0.65583253],
#        [-1.51272013],
#        [-1.98142493],
#        [-1.60380194],
#        [-1.21075439],
#        [-1.10945803],
#        [-1.05265997],
#        [-1.16872894],
#        [-1.18512432],
#        [-1.08639796],
#        [-0.83700699],
#        [-0.6291215 ],
#        [-0.35423044],
#        [-0.21431216],
#        [-0.24920847],
#        [-0.11271437],
#        [ 0.11315185],
#        [ 0.15775029],
#        [-0.00510886],
#        [ 0.1483316 ],
#        [ 0.52782378],
#        [ 0.43171258],
#        [ 0.16207481]])

# %%
# 2차원 -> 1차원 리스트에 담기
oil_list=[]
for i in oilScale :
    oil_list.append(i[0])

oil_list
# Out:
# [1.5517810817078017,
#  1.7770179047894223,
#  1.9914322919897942,
#  1.8258579337838479,
#  1.43316017050542,
#  0.8864475094864112,
#  1.1197854171059942,
#  1.4735105715010626,
#  1.519593587318033,
#  1.3974724692551703,
#  1.309481605502942,
#  1.3122657332712886,
#  1.4682582882480513,
#  1.572542227145902,
#  1.3714547240028045,
#  1.2222370774512477,
#  1.237222370136146,
#  1.251464337413485,
#  1.4739371652717543,
#  1.5869587507363425,
#  1.6109908196987952,
#  1.4754138360164568,
#  1.3605370913189454,
#  1.4812371322009283,
#  1.3421569797932678,
#  1.4602364947754785,
#  1.4337863527702255,
#  1.4633977563356366,
#  1.4898682594666885,
#  1.604570604758264,
#  1.4906369689663879,
#  1.280272969064957,
#  1.1004116054145265,
#  0.6980973391783947,
#  0.3315460450768455,
#  -0.34757809834240083,
#  -0.895366341820757,
#  -0.5835521851269597,
#  -0.667327079323734,
#  -0.47523923833825255,
#  -0.2764608888385246,
#  -0.3245802735817949,
#  -0.6126522941105649,
#  -0.9473423109169234,
#  -0.9380863896596104,
#  -0.9154191547314732,
#  -1.0652586250155311,
#  -1.330615034136128,
#  -1.615083218694641,
#  -1.5819666718273464,
#  -1.3053030805482415,
#  -1.1617938263554441,
#  -0.9514409713825441,
#  -0.8650572244040708,
#  -1.01537698557681,
#  -0.996449461764965,
#  -0.9920692142841455,
#  -0.7934335857318582,
#  -0.9786553758931279,
#  -0.6717533593627709,
#  -0.6361105477667136,
#  -0.606880599720034,
#  -0.750662836862407,
#  -0.6982685805254969,
#  -0.7924511273508711,
#  -0.9465444993356018,
#  -0.8885181125508573,
#  -0.7947481707315189,
#  -0.6769777480090357,
#  -0.5944351400363893,
#  -0.3799291203442675,
#  -0.3357598237088452,
#  -0.12572425180786112,
#  -0.24082689891185127,
#  -0.21792747883363306,
#  -0.02411213518360791,
#  0.17753361200556894,
#  0.11953731523643628,
#  0.14638548680592992,
#  0.08255534297560645,
#  0.2511247664164264,
#  0.3110127146337693,
#  -0.2725310876000007,
#  -0.6131312425712961,
#  -0.5099756753846445,
#  -0.3329192461672178,
#  -0.21926706566600832,
#  -0.02294244716899734,
#  -0.10210606261594107,
#  -0.3938269921503718,
#  -0.31675134225799956,
#  -0.47769326636687504,
#  -0.38214775534303225,
#  -0.4804708718337695,
#  -0.3617598972112697,
#  -0.2501821159292671,
#  -0.31198667222794,
#  -0.6558325332242371,
#  -1.512720131474313,
#  -1.9814249306717844,
#  -1.6038019371950656,
#  -1.2107543884621927,
#  -1.1094580297464027,
#  -1.0526599742212879,
#  -1.1687289357026098,
#  -1.185124320129855,
#  -1.0863979586874069,
#  -0.8370069889963019,
#  -0.629121498515167,
#  -0.35423043902783247,
#  -0.21431215700076406,
#  -0.24920846501207738,
#  -0.11271436864789278,
#  0.11315185232681181,
#  0.15775029199004229,
#  -0.005108863308855652,
#  0.14833160053668903,
#  0.5278237780347239,
#  0.4317125811744599,
#  0.16207480837113]

# %%
oil_df['oil_ss'] = oil_list
oil_df.head()
# Out:
#          date       Dubai       Brent         WTI     oil_avg    oil_ss
# 0  2012-01-31  109.456667  111.452381  100.289286  107.066111  1.551781
# 1  2012-02-29  116.180952  119.060000  102.370952  112.537302  1.777018
# 2  2012-03-31  122.487273  124.544545  106.205000  117.745606  1.991432
# 3  2012-04-30  117.338500  120.486500  103.346000  113.723667  1.825858
# 4  2012-05-31  107.719348  110.288696   94.546087  104.184710  1.433160

# %%
# 월별 닭고기, 수입량 정규화 그래프

plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_df['date']
y1 = price_df['price_ss']
y2 = oil_df['oil_ss']

fig, ax1 = plt.subplots()
ax1.set_title('월별 닭고기 가격,오일가격 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='blue',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('오일가격')
ax2.plot(x, y2, color='red',label='오일가격')

plt.xticks(['2012-01-31', '2013-01-31', '2014-01-31','2015-01-31','2016-01-31','2017-01-31', '2018-01-31', '2019-01-31', '2020-01-31', '2021-01-31'])
fig.legend()
plt.show()
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 그룹별 정규화 그래프 [ 닭고기(red) / 병아리(원/수)(blue) ]
#
# ##### 그래프를 설명할 기준, 지수화 시키기 위한 기준
# - 정규화 된 [ 닭고기 평균 값 / 병아리(원/수) 평균 값 ] 구하기
# - 각 값들이 평균으로부터 떨어진 거리 (분산 or 표준편차) 구하기
# - 평균 - 평균 후 값들이 떨어진 거리들도 같이 계산하기
#
# -생각해볼 부분
# - 평균대비 해석해도 가능 꼭지점 기준으로 해도되고 그래프도 가능...
# - 파란거 평균 선 으로 해석 가능
# - 평균 대비 폭 >> 평균끼리 차이점 구가늬 플마값을 거리 절대값

# %%
# 그래프 편차에 맞춰 닭고기 가격, 수입량 기간 분리
price_group1 = price_df.iloc[:23,:]
price_group2 = price_df.iloc[24:83,:]
price_group3 = price_df.iloc[84:,:]


oil_group1 = oil_df.iloc[:23,:]
oil_group2 = oil_df.iloc[24:83,:]
oil_group3 = oil_df.iloc[84:,:]

# %% [markdown]
# ##### 그래프 시각화

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group1['date']
y1 = price_group1['price_ss']
y2 = oil_group1['oil_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 오일가격 그룹1 (2012-2013) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('오일가격')
ax2.plot(x, y2, color='blue',label='오일가격')

plt.xticks(['2012-01-31', '2012-04-30', '2012-07-31', '2012-10-31', '2013-01-31', '2013-04-30', '2013-07-31', '2013-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group2['date']
y1 = price_group2['price_ss']
y2 = oil_group2['oil_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 오일가격 그룹2 (2014-2018) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('오일가격')
ax2.plot(x, y2, color='blue',label='오일가격')

plt.xticks(['2014-01-31', '2014-04-30', '2014-07-31', '2014-10-31', '2015-01-31', '2015-04-30', '2015-07-31', '2015-10-31', '2016-01-31', '2016-04-30', '2016-07-31', '2016-10-31',
             '2017-01-31', '2017-04-30', '2017-07-31', '2017-10-31', '2018-01-31', '2018-04-30', '2018-07-31', '2018-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group3['date']
y1 = price_group3['price_ss']
y2 = oil_group3['oil_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 오일가격 그룹3 (2019-2021) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('오일가격')
ax2.plot(x, y2, color='blue',label='오일가격')

plt.xticks(['2019-01-31', '2019-04-30', '2019-07-31', '2019-10-31', '2020-01-31', '2020-04-30', '2020-07-31', '2020-10-31', '2021-01-31', '2021-04-30', '2021-07-31', '2021-10-31'])
fig.legend()
plt.show()

# %% [markdown]
# ##### 그룹별 정규화된 병아리(원/수), 닭고기 가격 값 평균 구하기

# %%
price_ss_mean1 = price_group1['price_ss'].mean()
oil_ss_mean1 = oil_group1['oil_ss'].mean()

print(price_ss_mean1, oil_ss_mean1)
# Out:
# 0.8236048204131915 1.4447314332024832

# %%
price_ss_mean2 = price_group2['price_ss'].mean()
oil_ss_mean2 = oil_group2['oil_ss'].mean()

print(price_ss_mean2, oil_ss_mean2)
# Out:
# -0.05724049804498116 -0.27978200737920683

# %%
price_ss_mean3 = price_group3['price_ss'].mean()
oil_ss_mean3 = oil_group3['oil_ss'].mean()

print(price_ss_mean3, oil_ss_mean3)
# Out:
# -0.47074463000894234 -0.48860528938648673

# %% [markdown]
# ##### 그룹별 정규화된 수입량, 닭고기 가격 값 평균으로부터 떨어진 거리 구하기

# %%
price_group1['price_ss_mean'] = (price_group1['price_ss'] - price_ss_mean1).abs()
price_group2['price_ss_mean'] = (price_group2['price_ss'] - price_ss_mean2).abs()
price_group3['price_ss_mean'] = (price_group3['price_ss'] - price_ss_mean3).abs()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\1777069753.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group1['price_ss_mean'] = (price_group1['price_ss'] - price_ss_mean1).abs()
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\1777069753.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group2['price_ss_mean'] = (price_group2['price_ss'] - price_ss_mean2).abs()
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\1777069753.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group3['price_ss_mean'] = (price_group3['price_ss'] - price_ss_mean3).abs()

# %%
oil_group1['oil_ss_mean'] = (oil_group1['oil_ss'] - oil_ss_mean1).abs()
oil_group2['oil_ss_mean'] = (oil_group2['oil_ss'] - oil_ss_mean1).abs()
oil_group3['oil_ss_mean'] = (oil_group3['oil_ss'] - oil_ss_mean1).abs()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\2475025011.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil_group1['oil_ss_mean'] = (oil_group1['oil_ss'] - oil_ss_mean1).abs()
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\2475025011.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil_group2['oil_ss_mean'] = (oil_group2['oil_ss'] - oil_ss_mean1).abs()
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\2475025011.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil_group3['oil_ss_mean'] = (oil_group3['oil_ss'] - oil_ss_mean1).abs()
