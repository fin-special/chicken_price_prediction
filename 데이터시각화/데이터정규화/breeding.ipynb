# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
# 그래프 한글, 마이너스 깨짐 방지

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
# ## 닭고기가격, 병아리가격 그래프 시각화

# %%
price_df = pd.read_csv('../pre_data/월별_닭고기가격.csv', header=0, encoding='utf8')
price_df
# Out:
#      Unnamed: 0        date  price
# 0             0  2012-01-31   3202
# 1             1  2012-02-29   3668
# 2             2  2012-03-31   4169
# 3             3  2012-04-30   3399
# 4             4  2012-05-31   3255
# ..          ...         ...    ...
# 115         115  2021-08-31   3505
# 116         116  2021-09-30   3074
# 117         117  2021-10-31   3913
# 118         118  2021-11-30   2985
# 119         119  2021-12-31   3320
#
# [120 rows x 3 columns]

# %%
breeding_df = pd.read_csv('../pre_data/월별_종계입식현황.csv', encoding='utf8')
breeding_df
# Out:
#      Unnamed: 0        date  count
# 0             0  2012-01-31    356
# 1             1  2012-02-29    672
# 2             2  2012-03-31    870
# 3             3  2012-04-30    718
# 4             4  2012-05-31    496
# ..          ...         ...    ...
# 115         115  2021-08-31    670
# 116         116  2021-09-30    479
# 117         117  2021-10-31    591
# 118         118  2021-11-30    652
# 119         119  2021-12-31    444
#
# [120 rows x 3 columns]

# %%
breeding_df.drop(labels='Unnamed: 0',axis=1,inplace=True)

# %%
# 닭고기 가격, 수입량 기본 그래프

plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_df['date']
y1 = price_df['price']
y2 = breeding_df['count']

fig, ax1 = plt.subplots()
ax1.set_title('월별 닭고기, 종계입식현황 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='blue',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('종계입식현황')
ax2.plot(x, y2, color='red',label='종계입식현황')

plt.xticks(['2012-01-31', '2013-01-31', '2014-01-31','2015-01-31','2016-01-31','2017-01-31', '2018-01-31', '2019-01-31', '2020-01-31', '2021-01-31'])
fig.legend()
# plt.legend()
plt.show()

# %% [markdown]
# ### 병아리가격 데이터 범위 쪼개서 그래프 그리기

# %%
# 종계입식현황 범위 분리
breeding_group1 = breeding_df.iloc[:23,:]
breeding_group2 = breeding_df.iloc[24:83,:]
breeding_group3 = breeding_df.iloc[84:,:]

# %%
price_group1 = price_df.iloc[:23,:]
price_group2 = price_df.iloc[24:83,:]
price_group3 = price_df.iloc[84:,:]

# %% [markdown]
# #### 그룹별 시각화 그래프

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group1['date']
y1 = price_group1['price']
y2 = breeding_group1['count']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 종계입식현황 그룹1 (2012-2013) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('종계입식현황')
ax2.plot(x, y2, color='blue',label='종계입식현황')

plt.xticks(['2012-01-31', '2012-04-30', '2012-07-31', '2012-10-31', '2013-01-31', '2013-04-30', '2013-07-31', '2013-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group2['date']
y1 = price_group2['price']
y2 = breeding_group2['count']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 종계입식현황 그룹2 (2014-2018) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('종계입식현황')
ax2.plot(x, y2, color='blue',label='종계입식현황')

plt.xticks(['2014-01-31', '2014-04-30', '2014-07-31', '2014-10-31', '2015-01-31', '2015-04-30', '2015-07-31', '2015-10-31', '2016-01-31', '2016-04-30', '2016-07-31', '2016-10-31',
             '2017-01-31', '2017-04-30', '2017-07-31', '2017-10-31', '2018-01-31', '2018-04-30', '2018-07-31', '2018-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group3['date']
y1 = price_group3['price']
y2 = breeding_group3['count']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 종계입식현황 그룹3 (2019-2021) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('종계입식현황')
ax2.plot(x, y2, color='blue',label='종계입식현황')

plt.xticks(['2019-01-31', '2019-04-30', '2019-07-31', '2019-10-31', '2020-01-31', '2020-04-30', '2020-07-31', '2020-10-31', '2021-01-31', '2021-04-30', '2021-07-31', '2021-10-31'])
fig.legend()
plt.show()

# %% [markdown]
# ## 닭고기 - 수입량 나온 값을 그 값들의 평균을 내서, 평균으로부터의 값들의 거리를 계산
# - 거리를 양수값으로 변경해도 될듯 (절댓값 사용)
# - 그거에 대한 범주화 하기
#
# ### 닭고기 가격에 변동이 되는 이벤트 시점을 찾아보기
# - 물가동향, 금리인상, 복날, 전쟁
#
# ### 22년도 데이터들로 학습 모델에 테스트 해보기

# %% [markdown]
# ## 정규화
# - MinMaxScaler / StandardScaler 두 가지 방법이 있음
# - 두 개 다 돌려보고 정확도가 더 높은 함수를 사용함. 보통 잘 모를때는 StandardScaler 사용함. (해보고 별로면 MinMaxScaler 사용)
#
# - 배열화 처리 먼저 해주기 (numpy 사용)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
# 스케일링 함수
ss = StandardScaler()

# %% [markdown]
# #### 닭고기 가격 정규화 값 컬럼 추가 (배열화 > 스케일링 > 차원축소 > 컬럼추가)

# %%
# 닭고기 가격 데이터 배열화 처리
price_df2 = price_df[['price']].to_numpy()
price_df2
# Out:
# array([[3202],
#        [3668],
#        [4169],
#        [3399],
#        [3255],
#        [3493],
#        [3703],
#        [3745],
#        [3275],
#        [3520],
#        [3519],
#        [3340],
#        [3232],
#        [3935],
#        [4010],
#        [3295],
#        [3535],
#        [3762],
#        [4177],
#        [4015],
#        [3450],
#        [4092],
#        [3684],
#        [3316],
#        [3368],
#        [3391],
#        [3651],
#        [3964],
#        [3017],
#        [3118],
#        [3223],
#        [3249],
#        [3008],
#        [3632],
#        [3638],
#        [3745],
#        [3725],
#        [3802],
#        [3690],
#        [3549],
#        [3106],
#        [3157],
#        [3384],
#        [3192],
#        [2866],
#        [2944],
#        [2895],
#        [3215],
#        [3072],
#        [2938],
#        [3050],
#        [2793],
#        [2898],
#        [3334],
#        [3172],
#        [3579],
#        [3223],
#        [3858],
#        [3158],
#        [2684],
#        [2733],
#        [3926],
#        [3818],
#        [3894],
#        [4456],
#        [3191],
#        [3221],
#        [2811],
#        [2664],
#        [3105],
#        [3063],
#        [2640],
#        [2513],
#        [2877],
#        [3243],
#        [3070],
#        [2977],
#        [2630],
#        [3297],
#        [3819],
#        [3057],
#        [3307],
#        [2938],
#        [3827],
#        [4281],
#        [3384],
#        [3397],
#        [3166],
#        [2841],
#        [2656],
#        [2783],
#        [2808],
#        [2524],
#        [3011],
#        [2500],
#        [2834],
#        [2750],
#        [2913],
#        [2834],
#        [2530],
#        [2457],
#        [2759],
#        [2972],
#        [3060],
#        [3053],
#        [2682],
#        [2931],
#        [3314],
#        [3985],
#        [3382],
#        [3148],
#        [3215],
#        [2923],
#        [2863],
#        [3646],
#        [3505],
#        [3074],
#        [3913],
#        [2985],
#        [3320]], dtype=int64)

# %%
ss.fit(price_df2)
priceScale=ss.transform(price_df2)
priceScale
# Out:
# array([[-0.15938547],
#        [ 0.91251299],
#        [ 2.06491884],
#        [ 0.29375615],
#        [-0.03747428],
#        [ 0.50997601],
#        [ 0.99302038],
#        [ 1.08962926],
#        [ 0.00852995],
#        [ 0.57208172],
#        [ 0.56978151],
#        [ 0.15804368],
#        [-0.09037914],
#        [ 1.5266694 ],
#        [ 1.69918525],
#        [ 0.05453418],
#        [ 0.60658489],
#        [ 1.12873285],
#        [ 2.08332053],
#        [ 1.7106863 ],
#        [ 0.41106693],
#        [ 1.88780257],
#        [ 0.94931637],
#        [ 0.10283861],
#        [ 0.2224496 ],
#        [ 0.27535446],
#        [ 0.8734094 ],
#        [ 1.59337553],
#        [-0.58492456],
#        [-0.35260322],
#        [-0.11108104],
#        [-0.05127554],
#        [-0.60562646],
#        [ 0.82970538],
#        [ 0.84350665],
#        [ 1.08962926],
#        [ 1.04362503],
#        [ 1.2207413 ],
#        [ 0.96311764],
#        [ 0.63878784],
#        [-0.38020576],
#        [-0.26289498],
#        [ 0.25925298],
#        [-0.18238759],
#        [-0.93225647],
#        [-0.75283999],
#        [-0.86555034],
#        [-0.12948273],
#        [-0.45841294],
#        [-0.76664125],
#        [-0.50901759],
#        [-1.10017189],
#        [-0.85864971],
#        [ 0.14424242],
#        [-0.22839181],
#        [ 0.70779418],
#        [-0.11108104],
#        [ 1.34955313],
#        [-0.26059477],
#        [-1.35089492],
#        [-1.23818457],
#        [ 1.5059675 ],
#        [ 1.25754468],
#        [ 1.43236074],
#        [ 2.72507948],
#        [-0.1846878 ],
#        [-0.11568146],
#        [-1.05876809],
#        [-1.39689915],
#        [-0.38250597],
#        [-0.47911484],
#        [-1.45210422],
#        [-1.74423105],
#        [-0.90695414],
#        [-0.06507681],
#        [-0.46301336],
#        [-0.67693301],
#        [-1.47510633],
#        [ 0.0591346 ],
#        [ 1.25984489],
#        [-0.49291611],
#        [ 0.08213671],
#        [-0.76664125],
#        [ 1.27824658],
#        [ 2.32254251],
#        [ 0.25925298],
#        [ 0.28915573],
#        [-0.24219308],
#        [-0.98976175],
#        [-1.41530084],
#        [-1.123174  ],
#        [-1.06566872],
#        [-1.71892873],
#        [-0.59872583],
#        [-1.7741338 ],
#        [-1.00586323],
#        [-1.19908098],
#        [-0.82414654],
#        [-1.00586323],
#        [-1.70512746],
#        [-1.87304289],
#        [-1.17837908],
#        [-0.68843407],
#        [-0.48601548],
#        [-0.50211696],
#        [-1.35549534],
#        [-0.78274273],
#        [ 0.09823819],
#        [ 1.64167997],
#        [ 0.25465256],
#        [-0.28359688],
#        [-0.12948273],
#        [-0.80114442],
#        [-0.9391571 ],
#        [ 0.86190834],
#        [ 0.53757855],
#        [-0.45381252],
#        [ 1.47606475],
#        [-0.65853132],
#        [ 0.11203946]])

# %%
# 2차원 -> 1차원 리스트에 담기
price_list=[]
for i in priceScale :
    price_list.append(i[0])

price_list
# Out:
# [-0.1593854739813105,
#  0.9125129872375594,
#  2.064918843612353,
#  0.2937561501820315,
#  -0.037474275602340325,
#  0.5099760114579408,
#  0.9930203823934831,
#  1.0896292565805914,
#  0.008529950201044646,
#  0.5720817162925106,
#  0.5697815050023413,
#  0.1580436840620458,
#  -0.09037913527623305,
#  1.5266694017127487,
#  1.6991852484754424,
#  0.05453417600442962,
#  0.6065848856450493,
#  1.1287328485134687,
#  2.083320533933707,
#  1.7106863049262886,
#  0.41106692598066313,
#  1.8878025742693207,
#  0.9493163678802673,
#  0.10283861309798384,
#  0.22244960018678478,
#  0.27535445986067747,
#  0.8734093953046821,
#  1.593375529127657,
#  -0.5849245626626215,
#  -0.3526032223555274,
#  -0.11108103688775628,
#  -0.051275543343355816,
#  -0.6056264642741448,
#  0.8297053807914664,
#  0.8435066485324819,
#  1.0896292565805914,
#  1.0436250307772066,
#  1.2207413001202387,
#  0.9631176356212828,
#  0.6387878437074188,
#  -0.3802057578375584,
#  -0.2628949820389267,
#  0.2592529808294928,
#  -0.182387586883003,
#  -0.932256467478178,
#  -0.7528399868449767,
#  -0.8655503400632698,
#  -0.12948272720911028,
#  -0.4584129417033128,
#  -0.7666412545859922,
#  -0.5090175900870363,
#  -1.1001718916605332,
#  -0.858649706192762,
#  0.14424241632103033,
#  -0.22839181268638797,
#  0.7077941824124963,
#  -0.11108103688775628,
#  1.3495531323697165,
#  -0.2605947707487574,
#  -1.3508949222889812,
#  -1.238184569070688,
#  1.5059675001012256,
#  1.2575446807629467,
#  1.4323607388158095,
#  2.7250794838909274,
#  -0.18468779817317224,
#  -0.11568145946809479,
#  -1.0587680884374868,
#  -1.3968991480923663,
#  -0.3825059691277276,
#  -0.47911484331483606,
#  -1.4521042190564282,
#  -1.7442310529079228,
#  -0.9069541432863163,
#  -0.06507681108437131,
#  -0.4630133642836513,
#  -0.6769330142693915,
#  -1.4751063319581208,
#  0.05913459858476812,
#  1.259844892053116,
#  -0.49291611105585154,
#  0.08213671148646061,
#  -0.7666412545859922,
#  1.27824658237447,
#  2.322542508111309,
#  0.2592529808294928,
#  0.289155727601693,
#  -0.24219308042740345,
#  -0.9897617497324093,
#  -1.4153008384137202,
#  -1.1231740045622256,
#  -1.0656687223079944,
#  -1.718928728716061,
#  -0.598725830403637,
#  -1.774133799680123,
#  -1.005863228763594,
#  -1.1990809771378108,
#  -0.8241465368402233,
#  -1.005863228763594,
#  -1.7051274609750455,
#  -1.8730428851574008,
#  -1.1783790755262877,
#  -0.6884340707202377,
#  -0.4860154771853438,
#  -0.5021169562165285,
#  -1.3554953448693199,
#  -0.7827427336171768,
#  0.09823819051764535,
#  1.6416799662212112,
#  0.2546525582491542,
#  -0.28359688365044994,
#  -0.12948272720911028,
#  -0.8011444239385309,
#  -0.9391571013486858,
#  0.8619083388538359,
#  0.5375785469399719,
#  -0.4538125191229743,
#  1.4760647533290252,
#  -0.6585313239480375,
#  0.11203945825866084]

# %%
price_df['price_ss'] = price_list
price_df
# Out:
#      Unnamed: 0        date  price  price_ss
# 0             0  2012-01-31   3202 -0.159385
# 1             1  2012-02-29   3668  0.912513
# 2             2  2012-03-31   4169  2.064919
# 3             3  2012-04-30   3399  0.293756
# 4             4  2012-05-31   3255 -0.037474
# ..          ...         ...    ...       ...
# 115         115  2021-08-31   3505  0.537579
# 116         116  2021-09-30   3074 -0.453813
# 117         117  2021-10-31   3913  1.476065
# 118         118  2021-11-30   2985 -0.658531
# 119         119  2021-12-31   3320  0.112039
#
# [120 rows x 4 columns]

# %%
price_df.drop(labels='Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# #### 원유가격 정규화 값 컬럼 추가 (배열화 > 스케일링 > 차원축소 > 컬럼추가)

# %%
# 종계입식현황 데이터 배열화 처리
breeding_df2 = breeding_df[['count']].to_numpy()

# %%
ss.fit(breeding_df2)
breedingScale=ss.transform(breeding_df2)
breedingScale
# Out:
# array([[-1.69491355e+00],
#        [ 4.55557285e-01],
#        [ 1.80300420e+00],
#        [ 7.68600508e-01],
#        [-7.42173308e-01],
#        [-1.80379815e+00],
#        [-1.14368527e+00],
#        [-7.83005033e-01],
#        [ 1.62929924e-01],
#        [ 1.42871339e+00],
#        [-7.62589171e-01],
#        [-2.26655770e+00],
#        [-1.97393034e+00],
#        [-1.49075493e+00],
#        [ 9.99980282e-01],
#        [ 1.49676627e+00],
#        [-4.80339873e-02],
#        [-1.38867562e+00],
#        [-6.80925721e-01],
#        [ 1.15650189e+00],
#        [ 7.34574071e-01],
#        [ 1.39468695e+00],
#        [ 8.80717619e-02],
#        [-1.53839194e+00],
#        [-2.24614184e+00],
#        [-1.66769240e+00],
#        [-3.06634911e-01],
#        [ 7.20963496e-01],
#        [ 1.76540499e-01],
#        [-8.57863195e-01],
#        [-7.62589171e-01],
#        [ 5.30415447e-01],
#        [ 1.99355225e+00],
#        [ 1.71453547e+00],
#        [ 1.42514062e-01],
#        [-6.74120434e-01],
#        [-1.20493286e+00],
#        [-7.48978596e-01],
#        [ 1.59204029e+00],
#        [ 1.02720143e+00],
#        [ 7.89016371e-01],
#        [ 4.72400371e-02],
#        [ 7.14158208e-01],
#        [-2.31776749e-01],
#        [-8.23836758e-01],
#        [-7.20226256e-03],
#        [-7.96615608e-01],
#        [-2.12364666e+00],
#        [-1.74255057e+00],
#        [ 3.19451536e-01],
#        [ 9.52343270e-01],
#        [ 2.10566936e-01],
#        [-3.06634911e-01],
#        [-7.83005033e-01],
#        [-6.19678134e-01],
#        [ 9.48770494e-02],
#        [ 7.89016371e-01],
#        [ 1.27219178e+00],
#        [ 6.25689471e-01],
#        [-6.53704571e-01],
#        [-6.53704571e-01],
#        [ 6.76558995e-02],
#        [ 6.52910621e-01],
#        [ 1.22098199e-01],
#        [ 1.01359086e+00],
#        [-8.57863195e-01],
#        [-9.32721357e-01],
#        [-2.52192611e-01],
#        [ 1.76897777e+00],
#        [ 1.58523500e+00],
#        [ 8.36653383e-01],
#        [-6.84498497e-02],
#        [-8.10226183e-01],
#        [-1.72893999e+00],
#        [-2.00795678e+00],
#        [-6.19678134e-01],
#        [ 1.23816534e+00],
#        [ 1.54440328e+00],
#        [ 6.93742346e-01],
#        [ 1.01359086e+00],
#        [ 1.15650189e+00],
#        [ 8.23042808e-01],
#        [-1.16086862e-01],
#        [-1.06882711e+00],
#        [-8.71473770e-01],
#        [ 1.08164373e+00],
#        [ 1.06122787e+00],
#        [ 5.98468322e-01],
#        [ 5.23610159e-01],
#        [ 3.33062111e-01],
#        [ 1.48996098e+00],
#        [ 7.68600508e-01],
#        [ 2.30982799e-01],
#        [ 1.24497063e+00],
#        [ 6.66521196e-01],
#        [-2.93024336e-01],
#        [-6.80925721e-01],
#        [-7.01341584e-01],
#        [ 4.75973147e-01],
#        [-5.85651697e-01],
#        [-3.40661348e-01],
#        [ 2.37788086e-01],
#        [ 7.07352921e-01],
#        [ 7.27768783e-01],
#        [ 7.34574071e-01],
#        [ 2.37788086e-01],
#        [-2.31776749e-01],
#        [-4.63156523e-01],
#        [ 5.09999585e-01],
#        [ 1.28903487e-01],
#        [ 7.61795221e-01],
#        [-3.96975102e-04],
#        [-6.40093997e-01],
#        [-8.98694920e-01],
#        [-2.52192611e-01],
#        [ 4.41946710e-01],
#        [-8.57863195e-01],
#        [-9.56709996e-02],
#        [ 3.19451536e-01],
#        [-1.09604826e+00]])

# %%
# 2차원 -> 1차원 리스트에 담기
breeding_list=[]
for i in breedingScale :
    breeding_list.append(i[0])

breeding_list
# Out:
# [-1.694913553212763,
#  0.45555728487162106,
#  1.8030042024055073,
#  0.7686005081370694,
#  -0.7421733084918334,
#  -1.8037981526094407,
#  -1.1436852687670822,
#  -0.7830050332655875,
#  0.1629299239930498,
#  1.428713391979428,
#  -0.7625891708787105,
#  -2.266557700045321,
#  -1.9739303391667495,
#  -1.4907549293439923,
#  0.9999802818550094,
#  1.4967662666023513,
#  -0.04803398733801318,
#  -1.388675617409607,
#  -0.6809257213312022,
#  1.1565018934877336,
#  0.7345740708256077,
#  1.394686954667966,
#  0.08807176190783392,
#  -1.538391941580039,
#  -2.2461418376584437,
#  -1.6676924033635936,
#  -0.3066349109051227,
#  0.7209634959010229,
#  0.17654049891763454,
#  -0.8578631953508034,
#  -0.7625891708787105,
#  0.530415446956837,
#  1.9935522513496933,
#  1.7145354653957068,
#  0.14251406160617275,
#  -0.6741204338689099,
#  -1.2049328559277135,
#  -0.7489785959541257,
#  1.5920402910744444,
#  1.0272014317041789,
#  0.7890163705239465,
#  0.047240037134079794,
#  0.7141582084387306,
#  -0.23177674881990676,
#  -0.8238367580393416,
#  -0.0072022625642590475,
#  -0.7966156081901722,
#  -2.1236466633371816,
#  -1.7425505654488096,
#  0.319451535625774,
#  0.952343269618963,
#  0.2105669362290963,
#  -0.3066349109051227,
#  -0.7830050332655875,
#  -0.6196781341705709,
#  0.09487704937012628,
#  0.7890163705239465,
#  1.2721917803467038,
#  0.6256894714289299,
#  -0.6537045714820328,
#  -0.6537045714820328,
#  0.06765589952095685,
#  0.6529106212780994,
#  0.1220981992192957,
#  1.0135908567795942,
#  -0.8578631953508034,
#  -0.9327213574360194,
#  -0.2521926112067838,
#  1.7689777650940455,
#  1.585235003612152,
#  0.8366533827599929,
#  -0.06844984972489024,
#  -0.8102261831147569,
#  -1.7289399905242249,
#  -2.0079567764782116,
#  -0.6196781341705709,
#  1.238165343035242,
#  1.544403278838398,
#  0.6937423460518535,
#  1.0135908567795942,
#  1.1565018934877336,
#  0.8230428078354083,
#  -0.11608686196093673,
#  -1.0688271066818664,
#  -0.8714737702753881,
#  1.0816437314025178,
#  1.0612278690156407,
#  0.5984683215797605,
#  0.5236101594945446,
#  0.33306211055035867,
#  1.489960979140059,
#  0.7686005081370694,
#  0.23098279861597337,
#  1.2449706304975343,
#  0.6665211962026841,
#  -0.29302433598053795,
#  -0.6809257213312022,
#  -0.7013415837180792,
#  0.47597314725849815,
#  -0.5856516968591092,
#  -0.34066134821658445,
#  0.23778808607826574,
#  0.7073529209764382,
#  0.7277687833633153,
#  0.7345740708256077,
#  0.23778808607826574,
#  -0.23177674881990676,
#  -0.46315652253784684,
#  0.50999958456996,
#  0.12890348668158805,
#  0.761795220674777,
#  -0.000396975101966693,
#  -0.640093996557448,
#  -0.8986949201245575,
#  -0.2521926112067838,
#  0.4419467099470364,
#  -0.8578631953508034,
#  -0.09567099957405967,
#  0.319451535625774,
#  -1.0960482565310359]

# %%
breeding_df.head()
# Out:
#    Unnamed: 0        date  count
# 0           0  2012-01-31    356
# 1           1  2012-02-29    672
# 2           2  2012-03-31    870
# 3           3  2012-04-30    718
# 4           4  2012-05-31    496

# %%
breeding_df['breeding_ss'] = breeding_list
breeding_df.head()
# Out:
#    Unnamed: 0        date  count  breeding_ss
# 0           0  2012-01-31    356    -1.694914
# 1           1  2012-02-29    672     0.455557
# 2           2  2012-03-31    870     1.803004
# 3           3  2012-04-30    718     0.768601
# 4           4  2012-05-31    496    -0.742173

# %%
# 월별 닭고기, 수입량 정규화 그래프

plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_df['date']
y1 = price_df['price_ss']
y2 = breeding_df['breeding_ss']

fig, ax1 = plt.subplots()
ax1.set_title('월별 닭고기 가격,종계입식현황 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='blue',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('종계입식현황')
ax2.plot(x, y2, color='red',label='종계입식현황')

plt.xticks(['2012-01-31', '2013-01-31', '2014-01-31','2015-01-31','2016-01-31','2017-01-31', '2018-01-31', '2019-01-31', '2020-01-31', '2021-01-31'])
fig.legend()
plt.show()
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 그룹별 정규화 그래프 [ 닭고기(red) / 병아리(원/수)(blue) ]
#
# ##### 그래프를 설명할 기준, 지수화 시키기 위한 기준
# - 정규화 된 [ 닭고기 평균 값 / 병아리(원/수) 평균 값 ] 구하기
# - 각 값들이 평균으로부터 떨어진 거리 (분산 or 표준편차) 구하기
# - 평균 - 평균 후 값들이 떨어진 거리들도 같이 계산하기
#
# -생각해볼 부분
# - 평균대비 해석해도 가능 꼭지점 기준으로 해도되고 그래프도 가능...
# - 파란거 평균 선 으로 해석 가능
# - 평균 대비 폭 >> 평균끼리 차이점 구가늬 플마값을 거리 절대값

# %%
# 그래프 편차에 맞춰 닭고기 가격, 수입량 기간 분리
price_group1 = price_df.iloc[:23,:]
price_group2 = price_df.iloc[24:83,:]
price_group3 = price_df.iloc[84:,:]


breeding_group1 = breeding_df.iloc[:23,:]
breeding_group2 = breeding_df.iloc[24:83,:]
breeding_group3 = breeding_df.iloc[84:,:]

# %% [markdown]
# ##### 그래프 시각화

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group1['date']
y1 = price_group1['price_ss']
y2 = breeding_group1['breeding_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 종계입식현황 그룹1 (2012-2013) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('종계입식현황')
ax2.plot(x, y2, color='blue',label='종계입식현황')

plt.xticks(['2012-01-31', '2012-04-30', '2012-07-31', '2012-10-31', '2013-01-31', '2013-04-30', '2013-07-31', '2013-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group2['date']
y1 = price_group2['price_ss']
y2 = breeding_group2['breeding_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 종계입식현황 그룹2 (2014-2018) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('종계입식현황')
ax2.plot(x, y2, color='blue',label='종계입식현황')

plt.xticks(['2014-01-31', '2014-04-30', '2014-07-31', '2014-10-31', '2015-01-31', '2015-04-30', '2015-07-31', '2015-10-31', '2016-01-31', '2016-04-30', '2016-07-31', '2016-10-31',
             '2017-01-31', '2017-04-30', '2017-07-31', '2017-10-31', '2018-01-31', '2018-04-30', '2018-07-31', '2018-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group3['date']
y1 = price_group3['price_ss']
y2 = breeding_group3['breeding_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 종계입식현황 그룹3 (2019-2021) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('종계입식현황')
ax2.plot(x, y2, color='blue',label='종계입식현황')

plt.xticks(['2019-01-31', '2019-04-30', '2019-07-31', '2019-10-31', '2020-01-31', '2020-04-30', '2020-07-31', '2020-10-31', '2021-01-31', '2021-04-30', '2021-07-31', '2021-10-31'])
fig.legend()
plt.show()

# %% [markdown]
# ##### 그룹별 정규화된 병아리(원/수), 닭고기 가격 값 평균 구하기

# %%
price_ss_mean1 = price_group1['price_ss'].mean()
breeding_ss_mean1 = breeding_group1['breeding_ss'].mean()

print(price_ss_mean1, breeding_ss_mean1)
# Out:
# 0.8236048204131915 -0.18650679309248372

# %%
price_ss_mean2 = price_group2['price_ss'].mean()
breeding_ss_mean2 = breeding_group2['breeding_ss'].mean()

print(price_ss_mean2, breeding_ss_mean2)
# Out:
# -0.05724049804498116 0.027516237878961274

# %%
price_ss_mean3 = price_group3['price_ss'].mean()
breeding_ss_mean3 = breeding_group3['breeding_ss'].mean()

print(price_ss_mean3, breeding_ss_mean3)
# Out:
# -0.47074463000894234 0.14648381262584328

# %% [markdown]
# ##### 그룹별 정규화된 수입량, 닭고기 가격 값 평균으로부터 떨어진 거리 구하기

# %%
price_group1['price_ss_mean'] = (price_group1['price_ss'] - price_ss_mean1).abs()
price_group2['price_ss_mean'] = (price_group2['price_ss'] - price_ss_mean2).abs()
price_group3['price_ss_mean'] = (price_group3['price_ss'] - price_ss_mean3).abs()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\1777069753.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group1['price_ss_mean'] = (price_group1['price_ss'] - price_ss_mean1).abs()
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\1777069753.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group2['price_ss_mean'] = (price_group2['price_ss'] - price_ss_mean2).abs()
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\1777069753.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group3['price_ss_mean'] = (price_group3['price_ss'] - price_ss_mean3).abs()

# %%
breeding_group1['breeding_ss_mean'] = (breeding_group1['breeding_ss'] - breeding_ss_mean1).abs()
breeding_group2['breeding_ss_mean'] = (breeding_group2['breeding_ss'] - breeding_ss_mean1).abs()
breeding_group3['breeding_ss_mean'] = (breeding_group3['breeding_ss'] - breeding_ss_mean1).abs()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\3517382037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   breeding_group1['breeding_ss_mean'] = (breeding_group1['breeding_ss'] - breeding_ss_mean1).abs()
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\3517382037.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   breeding_group2['breeding_ss_mean'] = (breeding_group2['breeding_ss'] - breeding_ss_mean1).abs()
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\3517382037.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   breeding_group3['breeding_ss_mean'] = (breeding_group3['breeding_ss'] - breeding_ss_mean1).abs()
