# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
# 그래프 한글, 마이너스 깨짐 방지

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
# ## 닭고기가격, 도축현황 그래프 시각화

# %%
price_df = pd.read_csv('../pre_data/월별_닭고기가격.csv', header=0, encoding='utf8')
price_df
# Out:
#      Unnamed: 0        date  price
# 0             0  2012-01-31   3202
# 1             1  2012-02-29   3668
# 2             2  2012-03-31   4169
# 3             3  2012-04-30   3399
# 4             4  2012-05-31   3255
# ..          ...         ...    ...
# 115         115  2021-08-31   3505
# 116         116  2021-09-30   3074
# 117         117  2021-10-31   3913
# 118         118  2021-11-30   2985
# 119         119  2021-12-31   3320
#
# [120 rows x 3 columns]

# %%
chicken_df = pd.read_csv('../pre_data/월별_도축현황.csv', encoding='utf8')
chicken_df
# Out:
#      Unnamed: 0        date     도축
# 0             0  2012-01-31  58873
# 1             1  2012-02-29  55879
# 2             2  2012-03-31  58750
# 3             3  2012-04-30  60940
# 4             4  2012-05-31  73505
# ..          ...         ...    ...
# 115         115  2021-08-31  89892
# 116         116  2021-09-30  81026
# 117         117  2021-10-31  81228
# 118         118  2021-11-30  86819
# 119         119  2021-12-31  90151
#
# [120 rows x 3 columns]

# %%
# 닭고기 가격, 수입량 기본 그래프

plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_df['date']
y1 = price_df['price']
y2 = chicken_df['도축']

fig, ax1 = plt.subplots()
ax1.set_title('월별 닭고기,도축량 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='blue',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('도축량')
ax2.plot(x, y2, color='red',label='도축량')

plt.xticks(['2012-01-31', '2013-01-31', '2014-01-31','2015-01-31','2016-01-31','2017-01-31', '2018-01-31', '2019-01-31', '2020-01-31', '2021-01-31'])
fig.legend()
# plt.legend()
plt.show()

# %% [markdown]
# ### 수입량 데이터 범위 쪼개서 그래프 그리기

# %%
# 도축량 범위 분리
chicken_group1 = chicken_df.iloc[:23,:]
chicken_group2 = chicken_df.iloc[24:83,:]
chicken_group3 = chicken_df.iloc[84:,:]

# %%
#  닭고기 가격 기간 분리
price_group1 = price_df.iloc[:23,:]
price_group2 = price_df.iloc[24:83,:]
price_group3 = price_df.iloc[84:,:]

# %% [markdown]
# #### 그룹별 시각화 그래프

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group1['date']
y1 = price_group1['price']
y2 = chicken_group1['도축']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 도축량 그룹1 (2012-2013) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('도축량')
ax2.plot(x, y2, color='blue',label='도축량')

plt.xticks(['2012-01-31', '2012-04-30', '2012-07-31', '2012-10-31', '2013-01-31', '2013-04-30', '2013-07-31', '2013-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group2['date']
y1 = price_group2['price']
y2 = chicken_group2['도축']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 도축량 그룹2 (2014-2018) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('도축량')
ax2.plot(x, y2, color='blue',label='도축량')

plt.xticks(['2014-01-31', '2014-04-30', '2014-07-31', '2014-10-31', '2015-01-31', '2015-04-30', '2015-07-31', '2015-10-31', '2016-01-31', '2016-04-30', '2016-07-31', '2016-10-31',
             '2017-01-31', '2017-04-30', '2017-07-31', '2017-10-31', '2018-01-31', '2018-04-30', '2018-07-31', '2018-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group3['date']
y1 = price_group3['price']
y2 = chicken_group3['도축']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 도축량 그룹3 (2019-2021) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('도축량')
ax2.plot(x, y2, color='blue',label='도축량')

plt.xticks(['2012-01-31', '2012-04-30', '2012-07-31', '2012-10-31', '2013-01-31', '2013-04-30', '2013-07-31', '2013-10-31'])
fig.legend()
plt.show()

# %% [markdown]
# ## 닭고기 - 도축량 나온 값을 그 값들의 평균을 내서, 평균으로부터의 값들의 거리를 계산
# - 거리를 양수값으로 변경해도 될듯 (절댓값 사용)
# - 그거에 대한 범주화 하기
#
# ### 닭고기 가격에 변동이 되는 이벤트 시점을 찾아보기
# - 물가동향, 금리인상, 복날, 전쟁
#
# ### 22년도 데이터들로 학습 모델에 테스트 해보기

# %% [markdown]
# ## 정규화
# - MinMaxScaler / StandardScaler 두 가지 방법이 있음
# - 두 개 다 돌려보고 정확도가 더 높은 함수를 사용함. 보통 잘 모를때는 StandardScaler 사용함. (해보고 별로면 MinMaxScaler 사용)
#
# - 배열화 처리 먼저 해주기 (numpy 사용)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
# 스케일링 함수
ss = StandardScaler()

# %% [markdown]
# #### 닭고기 가격 정규화 값 컬럼 추가 (배열화 > 스케일링 > 차원축소 > 컬럼추가)

# %%
# 닭고기 가격 데이터 배열화 처리
price_df2 = price_df[['price']].to_numpy()
price_df2
# Out:
# array([[3202],
#        [3668],
#        [4169],
#        [3399],
#        [3255],
#        [3493],
#        [3703],
#        [3745],
#        [3275],
#        [3520],
#        [3519],
#        [3340],
#        [3232],
#        [3935],
#        [4010],
#        [3295],
#        [3535],
#        [3762],
#        [4177],
#        [4015],
#        [3450],
#        [4092],
#        [3684],
#        [3316],
#        [3368],
#        [3391],
#        [3651],
#        [3964],
#        [3017],
#        [3118],
#        [3223],
#        [3249],
#        [3008],
#        [3632],
#        [3638],
#        [3745],
#        [3725],
#        [3802],
#        [3690],
#        [3549],
#        [3106],
#        [3157],
#        [3384],
#        [3192],
#        [2866],
#        [2944],
#        [2895],
#        [3215],
#        [3072],
#        [2938],
#        [3050],
#        [2793],
#        [2898],
#        [3334],
#        [3172],
#        [3579],
#        [3223],
#        [3858],
#        [3158],
#        [2684],
#        [2733],
#        [3926],
#        [3818],
#        [3894],
#        [4456],
#        [3191],
#        [3221],
#        [2811],
#        [2664],
#        [3105],
#        [3063],
#        [2640],
#        [2513],
#        [2877],
#        [3243],
#        [3070],
#        [2977],
#        [2630],
#        [3297],
#        [3819],
#        [3057],
#        [3307],
#        [2938],
#        [3827],
#        [4281],
#        [3384],
#        [3397],
#        [3166],
#        [2841],
#        [2656],
#        [2783],
#        [2808],
#        [2524],
#        [3011],
#        [2500],
#        [2834],
#        [2750],
#        [2913],
#        [2834],
#        [2530],
#        [2457],
#        [2759],
#        [2972],
#        [3060],
#        [3053],
#        [2682],
#        [2931],
#        [3314],
#        [3985],
#        [3382],
#        [3148],
#        [3215],
#        [2923],
#        [2863],
#        [3646],
#        [3505],
#        [3074],
#        [3913],
#        [2985],
#        [3320]], dtype=int64)

# %%
ss.fit(price_df2)
priceScale=ss.transform(price_df2)
priceScale
# Out:
# array([[-0.15938547],
#        [ 0.91251299],
#        [ 2.06491884],
#        [ 0.29375615],
#        [-0.03747428],
#        [ 0.50997601],
#        [ 0.99302038],
#        [ 1.08962926],
#        [ 0.00852995],
#        [ 0.57208172],
#        [ 0.56978151],
#        [ 0.15804368],
#        [-0.09037914],
#        [ 1.5266694 ],
#        [ 1.69918525],
#        [ 0.05453418],
#        [ 0.60658489],
#        [ 1.12873285],
#        [ 2.08332053],
#        [ 1.7106863 ],
#        [ 0.41106693],
#        [ 1.88780257],
#        [ 0.94931637],
#        [ 0.10283861],
#        [ 0.2224496 ],
#        [ 0.27535446],
#        [ 0.8734094 ],
#        [ 1.59337553],
#        [-0.58492456],
#        [-0.35260322],
#        [-0.11108104],
#        [-0.05127554],
#        [-0.60562646],
#        [ 0.82970538],
#        [ 0.84350665],
#        [ 1.08962926],
#        [ 1.04362503],
#        [ 1.2207413 ],
#        [ 0.96311764],
#        [ 0.63878784],
#        [-0.38020576],
#        [-0.26289498],
#        [ 0.25925298],
#        [-0.18238759],
#        [-0.93225647],
#        [-0.75283999],
#        [-0.86555034],
#        [-0.12948273],
#        [-0.45841294],
#        [-0.76664125],
#        [-0.50901759],
#        [-1.10017189],
#        [-0.85864971],
#        [ 0.14424242],
#        [-0.22839181],
#        [ 0.70779418],
#        [-0.11108104],
#        [ 1.34955313],
#        [-0.26059477],
#        [-1.35089492],
#        [-1.23818457],
#        [ 1.5059675 ],
#        [ 1.25754468],
#        [ 1.43236074],
#        [ 2.72507948],
#        [-0.1846878 ],
#        [-0.11568146],
#        [-1.05876809],
#        [-1.39689915],
#        [-0.38250597],
#        [-0.47911484],
#        [-1.45210422],
#        [-1.74423105],
#        [-0.90695414],
#        [-0.06507681],
#        [-0.46301336],
#        [-0.67693301],
#        [-1.47510633],
#        [ 0.0591346 ],
#        [ 1.25984489],
#        [-0.49291611],
#        [ 0.08213671],
#        [-0.76664125],
#        [ 1.27824658],
#        [ 2.32254251],
#        [ 0.25925298],
#        [ 0.28915573],
#        [-0.24219308],
#        [-0.98976175],
#        [-1.41530084],
#        [-1.123174  ],
#        [-1.06566872],
#        [-1.71892873],
#        [-0.59872583],
#        [-1.7741338 ],
#        [-1.00586323],
#        [-1.19908098],
#        [-0.82414654],
#        [-1.00586323],
#        [-1.70512746],
#        [-1.87304289],
#        [-1.17837908],
#        [-0.68843407],
#        [-0.48601548],
#        [-0.50211696],
#        [-1.35549534],
#        [-0.78274273],
#        [ 0.09823819],
#        [ 1.64167997],
#        [ 0.25465256],
#        [-0.28359688],
#        [-0.12948273],
#        [-0.80114442],
#        [-0.9391571 ],
#        [ 0.86190834],
#        [ 0.53757855],
#        [-0.45381252],
#        [ 1.47606475],
#        [-0.65853132],
#        [ 0.11203946]])

# %%
# 2차원 -> 1차원 리스트에 담기
price_list=[]
for i in priceScale :
    price_list.append(i[0])

price_list
# Out:
# [-0.1593854739813105,
#      Unnamed: 0        date  price  price_ss
# 0             0  2012-01-31   3202 -0.159385
# 1             1  2012-02-29   3668  0.912513
# 2             2  2012-03-31   4169  2.064919
# 3             3  2012-04-30   3399  0.293756
# 4             4  2012-05-31   3255 -0.037474
# ..          ...         ...    ...       ...
# 115         115  2021-08-31   3505  0.537579
# 116         116  2021-09-30   3074 -0.453813
# 117         117  2021-10-31   3913  1.476065
# 118         118  2021-11-30   2985 -0.658531
# 119         119  2021-12-31   3320  0.112039
#
# [120 rows x 4 columns]

# %% [markdown]
# #### 도축량 정규화 값 컬럼 추가 (배열화 > 스케일링 > 차원축소 > 컬럼추가)

# %%
# 수입량 데이터 배열화 처리
chicken_df2 = chicken_df[['도축']].to_numpy()

# %%
ss.fit(chicken_df2)
chickenScale=ss.transform(chicken_df2)
chickenScale
# Out:
# array([[-1.51844342],
#        [-1.73966186],
#        [-1.52753156],
#        [-1.36571847],
#        [-0.43732511],
#        [-0.40799187],
#        [ 1.00916567],
#        [-0.53980674],
#        [-1.66717847],
#        [-1.33638523],
#        [-1.40155379],
#        [-1.26833507],
#        [-1.4043615 ],
#        [-2.34088245],
#        [-1.70508263],
#        [-1.28326029],
#        [-0.77070441],
#        [-0.54224502],
#        [ 0.96128673],
#        [-0.30011648],
#        [-1.5620369 ],
#        [-1.16733119],
#        [-1.16836561],
#        [-0.68152249],
#        [-1.17560656],
#        [-1.09499557],
#        [-1.23560301],
#        [-1.02088665],
#        [-0.01978824],
#        [ 0.13781328],
#        [ 1.92640205],
#        [ 0.17165364],
#        [-0.68795068],
#        [-0.62662426],
#        [-1.06241129],
#        [-0.31873607],
#        [-0.69393555],
#        [-1.44928495],
#        [-0.54372276],
#        [-0.32486871],
#        [ 0.17896848],
#        [ 0.9156244 ],
#        [ 2.66704789],
#        [ 0.82710747],
#        [-0.32043548],
#        [-0.01239951],
#        [-0.35900462],
#        [ 0.14025156],
#        [-0.51749279],
#        [-0.65455364],
#        [ 0.25100855],
#        [ 0.17453524],
#        [ 0.51087002],
#        [ 0.78388343],
#        [ 2.0739549 ],
#        [ 0.80235524],
#        [-0.43060137],
#        [-0.31829275],
#        [ 0.06665985],
#        [ 0.17409192],
#        [-0.77971865],
#        [-1.27129056],
#        [-0.54401831],
#        [-0.91500621],
#        [-0.15019924],
#        [ 0.6721659 ],
#        [ 1.73451685],
#        [ 0.70859232],
#        [-0.02954136],
#        [-0.66378955],
#        [-0.1278114 ],
#        [ 0.10515511],
#        [ 0.29135099],
#        [-0.85818692],
#        [ 0.21901537],
#        [ 0.05845836],
#        [ 0.8194232 ],
#        [ 1.08475233],
#        [ 2.05673916],
#        [ 0.51604213],
#        [-0.56655392],
#        [ 0.2802679 ],
#        [ 0.11520378],
#        [-0.19357106],
#        [-0.08658232],
#        [-0.80735248],
#        [ 0.19611032],
#        [ 0.55475905],
#        [ 1.34993369],
#        [ 1.16070843],
#        [ 2.91989007],
#        [ 1.33353072],
#        [ 0.01915034],
#        [ 0.48619168],
#  2.9198900730983146,
#  1.333530716934739,
#  0.019150344936888573,
#  0.4861916812345114,
#  0.37403082875867033,
#  0.3987830590481346,
#  0.16980645705694125,
#  -0.13926392891568276,
#  0.49764420569680085,
#  0.8426976846573923,
#  0.9499080910753406,
#  1.3161672121048162,
#  2.677835427043733,
#  0.9032852334256332,
#  0.35615011314657974,
#  0.44555369120703275,
#  0.08646163387331231,
#  0.5630344260137438,
#  -0.41183401111817136,
#  -0.7981904653976002,
#  0.6754169402533711,
#  0.5425676564908136,
#  0.7512252634682677,
#  1.039016120117412,
#  1.9375590232522626,
#  0.7734653271014877,
#  0.1183809278585319,
#  0.13330615328680587,
#  0.5464097937297753,
#  0.7926021260417004]

# %%
chicken_df['chicken_ss'] = chicken_list
chicken_df.head()
# Out:
#    Unnamed: 0        date     도축  chicken_ss
# 0           0  2012-01-31  58873   -1.518443
# 1           1  2012-02-29  55879   -1.739662
# 2           2  2012-03-31  58750   -1.527532
# 3           3  2012-04-30  60940   -1.365718
# 4           4  2012-05-31  73505   -0.437325

# %%
# 월별 닭고기, 도축량 정규화 그래프

plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_df['date']
y1 = price_df['price_ss']
y2 = chicken_df['chicken_ss']

fig, ax1 = plt.subplots()
ax1.set_title('월별 닭고기 가격, 도축량 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='blue',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('닭고기 도축량')
ax2.plot(x, y2, color='red',label='도축량')

plt.xticks(['2012-01-31', '2013-01-31', '2014-01-31','2015-01-31','2016-01-31','2017-01-31', '2018-01-31', '2019-01-31', '2020-01-31', '2021-01-31'])
fig.legend()
plt.show()
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 그룹별 정규화 그래프 [ 닭고기(red) / 도축량(blue) ]
#
# ##### 그래프를 설명할 기준, 지수화 시키기 위한 기준
# - 정규화 된 [ 닭고기 평균 값 / 도축량 평균 값 ] 구하기
# - 각 값들이 평균으로부터 떨어진 거리 (분산 or 표준편차) 구하기
# - 평균 - 평균 후 값들이 떨어진 거리들도 같이 계산하기
#
# -생각해볼 부분
# - 평균대비 해석해도 가능 꼭지점 기준으로 해도되고 그래프도 가능...
# - 파란거 평균 선 으로 해석 가능
# - 평균 대비 폭 >> 평균끼리 차이점 구가늬 플마값을 거리 절대값

# %%
# 그래프 편차에 맞춰 닭고기 가격, 도축량 기간 분리
price_group1 = price_df.iloc[:23,:]
price_group2 = price_df.iloc[24:83,:]
price_group3 = price_df.iloc[84:,:]


# 도축량 범위 분리
chicken_group1 = chicken_df.iloc[:23,:]
chicken_group2 = chicken_df.iloc[24:83,:]
chicken_group3 = chicken_df.iloc[84:,:]

# %% [markdown]
# ##### 그래프 시각화

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group1['date']
y1 = price_group1['price_ss']
y2 = chicken_group1['chicken_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 도축량 그룹1 (2012-2013) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('도축량')
ax2.plot(x, y2, color='blue',label='도축량')

plt.xticks(['2012-01-31', '2012-04-30', '2012-07-31', '2012-10-31', '2013-01-31', '2013-04-30', '2013-07-31', '2013-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group2['date']
y1 = price_group2['price_ss']
y2 = chicken_group2['chicken_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 도축량 그룹2 (2014-2018) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('도축량')
ax2.plot(x, y2, color='blue',label='도축량')

plt.xticks(['2014-01-31', '2014-04-30', '2014-07-31', '2014-10-31', '2015-01-31', '2015-04-30', '2015-07-31', '2015-10-31', '2016-01-31', '2016-04-30', '2016-07-31', '2016-10-31',
             '2017-01-31', '2017-04-30', '2017-07-31', '2017-10-31', '2018-01-31', '2018-04-30', '2018-07-31', '2018-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group3['date']
y1 = price_group3['price_ss']
y2 = chicken_group3['chicken_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 도축량 그룹3 (2019-2021) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('도축량')
ax2.plot(x, y2, color='blue',label='도축량')

plt.xticks(['2019-01-31', '2019-04-30', '2019-07-31', '2019-10-31', '2020-01-31', '2020-04-30', '2020-07-31', '2020-10-31', '2021-01-31', '2021-04-30', '2021-07-31', '2021-10-31'])
fig.legend()
plt.show()

# %% [markdown]
# ##### 그룹별 정규화된 수입량, 닭고기 가격 값 평균 구하기

# %%
price_ss_mean1 = price_group1['price_ss'].mean()
chicken_ss_mean1 = chicken_group1['chicken_ss'].mean()

print(price_ss_mean1, chicken_ss_mean1)
# Out:
# 0.8236048204131915 -1.0210376377467043

# %%
price_ss_mean2 = price_group2['price_ss'].mean()
chicken_ss_mean2 = chicken_group2['chicken_ss'].mean()

print(price_ss_mean2, chicken_ss_mean2)
# Out:
# -0.05724049804498116 0.028654249600017556

# %%
price_ss_mean3 = price_group3['price_ss'].mean()
chicken_ss_mean3 = chicken_group3['chicken_ss'].mean()

print(price_ss_mean3, chicken_ss_mean3)
# Out:
# -0.47074463000894234 0.6296766248113312

# %% [markdown]
# ##### 그룹별 정규화된 도축량, 닭고기 가격 값 평균으로부터 떨어진 거리 구하기

# %%
price_group1['price_ss_mean'] = (price_group1['price_ss'] - price_ss_mean1).abs()
price_group1.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_21892\3153625502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group1['price_ss_mean'] = (price_group1['price_ss'] - price_ss_mean1).abs()
#    Unnamed: 0        date  price  price_ss  price_ss_mean
# 0           0  2012-01-31   3202 -0.159385       0.982990
# 1           1  2012-02-29   3668  0.912513       0.088908
# 2           2  2012-03-31   4169  2.064919       1.241314
# 3           3  2012-04-30   3399  0.293756       0.529849
# 4           4  2012-05-31   3255 -0.037474       0.861079

# %%
chicken_group1['chicken_ss_mean'] = (chicken_group1['chicken_ss'] - chicken_ss_mean1).abs()
chicken_group1.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_21892\871014627.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chicken_group1['chicken_ss_mean'] = (chicken_group1['chicken_ss'] - chicken_ss_mean1).abs()
#    Unnamed: 0        date     도축  chicken_ss  chicken_ss_mean
# 0           0  2012-01-31  58873   -1.518443         0.497406
# 1           1  2012-02-29  55879   -1.739662         0.718624
# 2           2  2012-03-31  58750   -1.527532         0.506494
# 3           3  2012-04-30  60940   -1.365718         0.344681
# 4           4  2012-05-31  73505   -0.437325         0.583713

# %%
price_group2['price_ss_mean'] = (price_group2['price_ss'] - price_ss_mean2).abs()
price_group2.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_21892\4256625362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group2['price_ss_mean'] = (price_group2['price_ss'] - price_ss_mean2).abs()
#     Unnamed: 0        date  price  price_ss  price_ss_mean
# 24          24  2014-01-31   3368  0.222450       0.279690
# 25          25  2014-02-28   3391  0.275354       0.332595
# 26          26  2014-03-31   3651  0.873409       0.930650
# 27          27  2014-04-30   3964  1.593376       1.650616
# 28          28  2014-05-31   3017 -0.584925       0.527684

# %%
chicken_group1.head()
# Out:
#    Unnamed: 0        date     도축  chicken_ss  chicken_ss_mean
# 0           0  2012-01-31  58873   -1.518443         0.497406
# 1           1  2012-02-29  55879   -1.739662         0.718624
# 2           2  2012-03-31  58750   -1.527532         0.506494
# 3           3  2012-04-30  60940   -1.365718         0.344681
# 4           4  2012-05-31  73505   -0.437325         0.583713

# %%
chicken_group2.head()
# Out:
#     Unnamed: 0        date     도축  chicken_ss
# 24          24  2014-01-31  63513   -1.175607
# 25          25  2014-02-28  64604   -1.094996
# 26          26  2014-03-31  62701   -1.235603
# 27          27  2014-04-30  65607   -1.020887
# 28          28  2014-05-31  79156   -0.019788

# %% [markdown]
# chicken_group2

# %%
chicken_group2['chicken_ss_mean'] = (chicken_group2['chicken_ss'] - chicken_ss_mean2).abs()
chicken_group2.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_21892\2642286381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chicken_group2['chicken_ss_mean'] = (chicken_group2['chicken_ss'] - chicken_ss_mean2).abs()
#     Unnamed: 0        date     도축  chicken_ss  chicken_ss_mean
# 24          24  2014-01-31  63513   -1.175607         1.204261
# 25          25  2014-02-28  64604   -1.094996         1.123650
# 26          26  2014-03-31  62701   -1.235603         1.264257
# 27          27  2014-04-30  65607   -1.020887         1.049541
# 28          28  2014-05-31  79156   -0.019788         0.048442

# %%
price_group3['price_ss_mean'] = (price_group3['price_ss'] - price_ss_mean3).abs()
price_group3.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_21892\1996725595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group3['price_ss_mean'] = (price_group3['price_ss'] - price_ss_mean3).abs()
#     Unnamed: 0        date  price  price_ss  price_ss_mean
# 84          84  2019-01-31   4281  2.322543       2.793287
# 85          85  2019-02-28   3384  0.259253       0.729998
# 86          86  2019-03-31   3397  0.289156       0.759900
# 87          87  2019-04-30   3166 -0.242193       0.228552
# 88          88  2019-05-31   2841 -0.989762       0.519017

# %%
chicken_group3['chicken_ss_mean'] = (chicken_group3['chicken_ss'] - chicken_ss_mean3).abs()
chicken_group3.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_21892\1760156680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chicken_group3['chicken_ss_mean'] = (chicken_group3['chicken_ss'] - chicken_ss_mean3).abs()
#     Unnamed: 0        date     도축  chicken_ss  chicken_ss_mean
# 84          84  2019-01-31  78252   -0.086582         0.716259
# 85          85  2019-02-28  68497   -0.807352         1.437029
# 86          86  2019-03-31  82078    0.196110         0.433566
# 87          87  2019-04-30  86932    0.554759         0.074918
# 88          88  2019-05-31  97694    1.349934         0.720257

# %% [markdown]
# ##### d
