# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
# 그래프 한글, 마이너스 깨짐 방지

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
# ## 닭고기가격, 사료값 그래프 시각화

# %%
price_df = pd.read_csv('../pre_data/월별_닭고기가격.csv', header=0, encoding='utf8')
price_df
# Out:
#      Unnamed: 0        date  price
# 0             0  2012-01-31   3202
# 1             1  2012-02-29   3668
# 2             2  2012-03-31   4169
# 3             3  2012-04-30   3399
# 4             4  2012-05-31   3255
# ..          ...         ...    ...
# 115         115  2021-08-31   3505
# 116         116  2021-09-30   3074
# 117         117  2021-10-31   3913
# 118         118  2021-11-30   2985
# 119         119  2021-12-31   3320
#
# [120 rows x 3 columns]

# %%
feed_df = pd.read_csv('../pre_data/월별_사료값.csv', encoding='utf8')
feed_df
# Out:
#      Unnamed: 0        date  feedprice
# 0             0  2012-01-31        533
# 1             1  2012-02-29        529
# 2             2  2012-03-31        527
# 3             3  2012-04-30        526
# 4             4  2012-05-31        526
# ..          ...         ...        ...
# 115         115  2021-08-31        492
# 116         116  2021-09-30        503
# 117         117  2021-10-31        508
# 118         118  2021-11-30        520
# 119         119  2021-12-31        511
#
# [120 rows x 3 columns]

# %%
feed_df.drop(labels='Unnamed: 0',axis=1,inplace=True)

# %%
# 닭고기 가격, 수입량 기본 그래프

plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_df['date']
y1 = price_df['price']
y2 = feed_df['feedprice']

fig, ax1 = plt.subplots()
ax1.set_title('월별 닭고기, 사료가격 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='blue',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('사료가격')
ax2.plot(x, y2, color='red',label='사료가격')

plt.xticks(['2012-01-31', '2013-01-31', '2014-01-31','2015-01-31','2016-01-31','2017-01-31', '2018-01-31', '2019-01-31', '2020-01-31', '2021-01-31'])
fig.legend()
# plt.legend()
plt.show()

# %% [markdown]
# ### 사료가격 데이터 범위 쪼개서 그래프 그리기

# %%
# 사료값 범위 분리
feed_group1 = feed_df.iloc[:23,:]
feed_group2 = feed_df.iloc[24:83,:]
feed_group3 = feed_df.iloc[84:,:]

# %%
price_group1 = price_df.iloc[:23,:]
price_group2 = price_df.iloc[24:83,:]
price_group3 = price_df.iloc[84:,:]

# %% [markdown]
# #### 그룹별 시각화 그래프

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group1['date']
y1 = price_group1['price']
y2 = feed_group1['feedprice']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 사료가격 그룹1 (2012-2013) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('사료가격')
ax2.plot(x, y2, color='blue',label='사료가격')

plt.xticks(['2012-01-31', '2012-04-30', '2012-07-31', '2012-10-31', '2013-01-31', '2013-04-30', '2013-07-31', '2013-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group2['date']
y1 = price_group2['price']
y2 = feed_group2['feedprice']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 사료가격 그룹2 (2014-2018) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('사료가격')
ax2.plot(x, y2, color='blue',label='사료가격')

plt.xticks(['2014-01-31', '2014-04-30', '2014-07-31', '2014-10-31', '2015-01-31', '2015-04-30', '2015-07-31', '2015-10-31', '2016-01-31', '2016-04-30', '2016-07-31', '2016-10-31',
             '2017-01-31', '2017-04-30', '2017-07-31', '2017-10-31', '2018-01-31', '2018-04-30', '2018-07-31', '2018-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_group3['date']
y1 = price_group3['price']
y2 = feed_group3['feedprice']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 사료가격 그룹3 (2019-2021) 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('사료가격')
ax2.plot(x, y2, color='blue',label='사료가격')

plt.xticks(['2019-01-31', '2019-04-30', '2019-07-31', '2019-10-31', '2020-01-31', '2020-04-30', '2020-07-31', '2020-10-31', '2021-01-31', '2021-04-30', '2021-07-31', '2021-10-31'])
fig.legend()
plt.show()

# %% [markdown]
# ## 닭고기 - 수입량 나온 값을 그 값들의 평균을 내서, 평균으로부터의 값들의 거리를 계산
# - 거리를 양수값으로 변경해도 될듯 (절댓값 사용)
# - 그거에 대한 범주화 하기
#
# ### 닭고기 가격에 변동이 되는 이벤트 시점을 찾아보기
# - 물가동향, 금리인상, 복날, 전쟁
#
# ### 22년도 데이터들로 학습 모델에 테스트 해보기

# %% [markdown]
# ## 정규화
# - MinMaxScaler / StandardScaler 두 가지 방법이 있음
# - 두 개 다 돌려보고 정확도가 더 높은 함수를 사용함. 보통 잘 모를때는 StandardScaler 사용함. (해보고 별로면 MinMaxScaler 사용)
#
# - 배열화 처리 먼저 해주기 (numpy 사용)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
# 스케일링 함수
ss = StandardScaler()

# %% [markdown]
# #### 닭고기 가격 정규화 값 컬럼 추가 (배열화 > 스케일링 > 차원축소 > 컬럼추가)

# %%
# 닭고기 가격 데이터 배열화 처리
price_df2 = price_df[['price']].to_numpy()
price_df2
# Out:
# array([[3202],
#        [3668],
#        [4169],
#        [3399],
#        [3255],
#        [3493],
#        [3703],
#        [3745],
#        [3275],
#        [3520],
#        [3519],
#        [3340],
#        [3232],
#        [3935],
#        [4010],
#        [3295],
#        [3535],
#        [3762],
#        [4177],
#        [4015],
#        [3450],
#        [4092],
#        [3684],
#        [3316],
#        [3368],
#        [3391],
#        [3651],
#        [3964],
#        [3017],
#        [3118],
#        [3223],
#        [3249],
#        [3008],
#        [3632],
#        [3638],
#        [3745],
#        [3725],
#        [3802],
#        [3690],
#        [3549],
#        [3106],
#        [3157],
#        [3384],
#        [3192],
#        [2866],
#        [2944],
#        [2895],
#        [3215],
#        [3072],
#        [2938],
#        [3050],
#        [2793],
#        [2898],
#        [3334],
#        [3172],
#        [3579],
#        [3223],
#        [3858],
#        [3158],
#        [2684],
#        [2733],
#        [3926],
#        [3818],
#        [3894],
#        [4456],
#        [3191],
#        [3221],
#        [2811],
#        [2664],
#        [3105],
#        [3063],
#        [2640],
#        [2513],
#        [2877],
#        [3243],
#        [3070],
#        [2977],
#        [2630],
#        [3297],
#        [3819],
#        [3057],
#        [3307],
#        [2938],
#        [3827],
#        [4281],
#        [3384],
#        [3397],
#        [3166],
#        [2841],
#        [2656],
#        [2783],
#        [2808],
#        [2524],
#        [3011],
#        [2500],
#        [2834],
#        [2750],
#        [2913],
#        [2834],
#        [2530],
#        [2457],
#        [2759],
#        [2972],
#        [3060],
#        [3053],
#        [2682],
#        [2931],
#        [3314],
#        [3985],
#        [3382],
#        [3148],
#        [3215],
#        [2923],
#        [2863],
#        [3646],
#        [3505],
#        [3074],
#        [3913],
#        [2985],
#        [3320]], dtype=int64)

# %%
ss.fit(price_df2)
priceScale=ss.transform(price_df2)
priceScale
# Out:
# array([[-0.15938547],
#        [ 0.91251299],
#        [ 2.06491884],
#        [ 0.29375615],
#        [-0.03747428],
#        [ 0.50997601],
#        [ 0.99302038],
#        [ 1.08962926],
#        [ 0.00852995],
#        [ 0.57208172],
#        [ 0.56978151],
#        [ 0.15804368],
#        [-0.09037914],
#        [ 1.5266694 ],
#        [ 1.69918525],
#        [ 0.05453418],
#        [ 0.60658489],
#        [ 1.12873285],
#        [ 2.08332053],
#        [ 1.7106863 ],
#        [ 0.41106693],
#        [ 1.88780257],
#        [ 0.94931637],
#        [ 0.10283861],
#        [ 0.2224496 ],
#        [ 0.27535446],
#        [ 0.8734094 ],
#        [ 1.59337553],
#        [-0.58492456],
#        [-0.35260322],
#        [-0.11108104],
#        [-0.05127554],
#        [-0.60562646],
#        [ 0.82970538],
#        [ 0.84350665],
#        [ 1.08962926],
#        [ 1.04362503],
#        [ 1.2207413 ],
#        [ 0.96311764],
#        [ 0.63878784],
#        [-0.38020576],
#        [-0.26289498],
#        [ 0.25925298],
#        [-0.18238759],
#        [-0.93225647],
#        [-0.75283999],
#        [-0.86555034],
#        [-0.12948273],
#        [-0.45841294],
#        [-0.76664125],
#        [-0.50901759],
#        [-1.10017189],
#        [-0.85864971],
#        [ 0.14424242],
#        [-0.22839181],
#        [ 0.70779418],
#        [-0.11108104],
#        [ 1.34955313],
#        [-0.26059477],
#        [-1.35089492],
#        [-1.23818457],
#        [ 1.5059675 ],
#        [ 1.25754468],
#        [ 1.43236074],
#        [ 2.72507948],
#        [-0.1846878 ],
#        [-0.11568146],
#        [-1.05876809],
#        [-1.39689915],
#        [-0.38250597],
#        [-0.47911484],
#        [-1.45210422],
#        [-1.74423105],
#        [-0.90695414],
#        [-0.06507681],
#        [-0.46301336],
#        [-0.67693301],
#        [-1.47510633],
#        [ 0.0591346 ],
#        [ 1.25984489],
#        [-0.49291611],
#        [ 0.08213671],
#        [-0.76664125],
#        [ 1.27824658],
#        [ 2.32254251],
#        [ 0.25925298],
#        [ 0.28915573],
#        [-0.24219308],
#        [-0.98976175],
#        [-1.41530084],
#        [-1.123174  ],
#        [-1.06566872],
#        [-1.71892873],
#        [-0.59872583],
#        [-1.7741338 ],
#        [-1.00586323],
#        [-1.19908098],
#        [-0.82414654],
#        [-1.00586323],
#        [-1.70512746],
#        [-1.87304289],
#        [-1.17837908],
#        [-0.68843407],
#        [-0.48601548],
#        [-0.50211696],
#        [-1.35549534],
#        [-0.78274273],
#        [ 0.09823819],
#        [ 1.64167997],
#        [ 0.25465256],
#        [-0.28359688],
#        [-0.12948273],
#        [-0.80114442],
#        [-0.9391571 ],
#        [ 0.86190834],
#        [ 0.53757855],
#        [-0.45381252],
#        [ 1.47606475],
#        [-0.65853132],
#        [ 0.11203946]])

# %%
# 2차원 -> 1차원 리스트에 담기
price_list=[]
for i in priceScale :
    price_list.append(i[0])

price_list
# Out:
# [-0.1593854739813105,
#  0.9125129872375594,
#  2.064918843612353,
#  0.2937561501820315,
#  -0.037474275602340325,
#  0.5099760114579408,
#  0.9930203823934831,
#  1.0896292565805914,
#  0.008529950201044646,
#  0.5720817162925106,
#  0.5697815050023413,
#  0.1580436840620458,
#  -0.09037913527623305,
#  1.5266694017127487,
#  1.6991852484754424,
#  0.05453417600442962,
#  0.6065848856450493,
#  1.1287328485134687,
#  2.083320533933707,
#  1.7106863049262886,
#  0.41106692598066313,
#  1.8878025742693207,
#  0.9493163678802673,
#  0.10283861309798384,
#  0.22244960018678478,
#  0.27535445986067747,
#  0.8734093953046821,
#  1.593375529127657,
#  -0.5849245626626215,
#  -0.3526032223555274,
#  -0.11108103688775628,
#  -0.051275543343355816,
#  -0.6056264642741448,
#  0.8297053807914664,
#  0.8435066485324819,
#  1.0896292565805914,
#  1.0436250307772066,
#  1.2207413001202387,
#  0.9631176356212828,
#  0.6387878437074188,
#  -0.3802057578375584,
#  -0.2628949820389267,
#  0.2592529808294928,
#  -0.182387586883003,
#  -0.932256467478178,
#  -0.7528399868449767,
#  -0.8655503400632698,
#  -0.12948272720911028,
#  -0.4584129417033128,
#  -0.7666412545859922,
#  -0.5090175900870363,
#  -1.1001718916605332,
#  -0.858649706192762,
#  0.14424241632103033,
#  -0.22839181268638797,
#  0.7077941824124963,
#  -0.11108103688775628,
#  1.3495531323697165,
#  -0.2605947707487574,
#  -1.3508949222889812,
#  -1.238184569070688,
#  1.5059675001012256,
#  1.2575446807629467,
#  1.4323607388158095,
#  2.7250794838909274,
#  -0.18468779817317224,
#  -0.11568145946809479,
#  -1.0587680884374868,
#  -1.3968991480923663,
#  -0.3825059691277276,
#  -0.47911484331483606,
#  -1.4521042190564282,
#  -1.7442310529079228,
#  -0.9069541432863163,
#  -0.06507681108437131,
#  -0.4630133642836513,
#  -0.6769330142693915,
#  -1.4751063319581208,
#  0.05913459858476812,
#  1.259844892053116,
#  -0.49291611105585154,
#  0.08213671148646061,
#  -0.7666412545859922,
#  1.27824658237447,
#  2.322542508111309,
#  0.2592529808294928,
#  0.289155727601693,
#  -0.24219308042740345,
#  -0.9897617497324093,
#  -1.4153008384137202,
#  -1.1231740045622256,
#  -1.0656687223079944,
#  -1.718928728716061,
#  -0.598725830403637,
#  -1.774133799680123,
#  -1.005863228763594,
#  -1.1990809771378108,
#  -0.8241465368402233,
#  -1.005863228763594,
#  -1.7051274609750455,
#  -1.8730428851574008,
#  -1.1783790755262877,
#  -0.6884340707202377,
#  -0.4860154771853438,
#  -0.5021169562165285,
#  -1.3554953448693199,
#  -0.7827427336171768,
#  0.09823819051764535,
#  1.6416799662212112,
#  0.2546525582491542,
#  -0.28359688365044994,
#  -0.12948272720911028,
#  -0.8011444239385309,
#  -0.9391571013486858,
#  0.8619083388538359,
#  0.5375785469399719,
#  -0.4538125191229743,
#  1.4760647533290252,
#  -0.6585313239480375,
#  0.11203945825866084]

# %%
price_df['price_ss'] = price_list
price_df
# Out:
#      Unnamed: 0        date  price  price_ss
# 0             0  2012-01-31   3202 -0.159385
# 1             1  2012-02-29   3668  0.912513
# 2             2  2012-03-31   4169  2.064919
# 3             3  2012-04-30   3399  0.293756
# 4             4  2012-05-31   3255 -0.037474
# ..          ...         ...    ...       ...
# 115         115  2021-08-31   3505  0.537579
# 116         116  2021-09-30   3074 -0.453813
# 117         117  2021-10-31   3913  1.476065
# 118         118  2021-11-30   2985 -0.658531
# 119         119  2021-12-31   3320  0.112039
#
# [120 rows x 4 columns]

# %% [markdown]
# #### 수입량 정규화 값 컬럼 추가 (배열화 > 스케일링 > 차원축소 > 컬럼추가)

# %%
# 수입량 데이터 배열화 처리
feed_df2 = feed_df[['feedprice']].to_numpy()

# %%
ss.fit(feed_df2)
feedScale=ss.transform(feed_df2)
feedScale
# Out:
# array([[ 1.66904875],
#        [ 1.57312641],
#        [ 1.52516524],
#        [ 1.50118465],
#        [ 1.50118465],
#        [ 1.78895168],
#        [ 1.71700992],
#        [ 1.59710699],
#        [ 1.62108758],
#        [ 1.74099051],
#        [ 1.62108758],
#        [ 0.9256506 ],
#        [ 1.45322348],
#        [ 1.33332055],
#        [ 1.74099051],
#        [ 1.86089344],
#        [ 1.95681578],
#        [ 2.02875753],
#        [ 1.93283519],
#        [ 1.78895168],
#        [ 1.45322348],
#        [ 1.35730114],
#        [ 1.28535938],
#        [ 1.14147587],
#        [ 0.90167001],
#        [ 0.90167001],
#        [ 0.80574767],
#        [ 0.90167001],
#        [ 0.97361177],
#        [ 0.9256506 ],
#        [ 0.87768943],
#        [ 0.63788357],
#        [ 0.7577865 ],
#        [ 0.39807772],
#        [ 0.44603889],
#        [ 0.51798065],
#        [ 0.37409713],
#        [ 0.30215538],
#        [ 0.15827186],
#        [ 0.01438835],
#        [ 0.06234952],
#        [-0.20143692],
#        [ 0.03836894],
#        [-0.15347575],
#        [-0.41726219],
#        [-0.29735926],
#        [-0.34532043],
#        [-0.51318453],
#        [-0.5611457 ],
#        [-0.53716512],
#        [-0.44124277],
#        [-0.53716512],
#        [-0.53716512],
#        [-0.82493214],
#        [-0.53716512],
#        [-0.7290098 ],
#        [-0.94483507],
#        [-0.99279624],
#        [-0.8968739 ],
#        [-0.87289331],
#        [-0.96881565],
#        [-0.99279624],
#        [-1.01677683],
#        [-0.92085448],
#        [-0.84891273],
#        [-0.65706804],
#        [-0.77697097],
#        [-0.82493214],
#        [-0.92085448],
#        [-0.94483507],
#        [-0.94483507],
#        [-1.064738  ],
#        [-1.13667975],
#        [-1.18464092],
#        [-1.11269917],
#        [-1.08871858],
#        [-0.94483507],
#        [-0.87289331],
#        [-0.94483507],
#        [-0.77697097],
#        [-0.60910687],
#        [-0.60910687],
#        [-0.60910687],
#        [-0.70502921],
#        [-0.75299038],
#        [-0.63308746],
#        [-0.63308746],
#        [-0.63308746],
#        [-0.60910687],
#        [-0.5611457 ],
#        [-0.70502921],
#        [-0.80095156],
#        [-0.8968739 ],
#        [-0.8968739 ],
#        [-0.94483507],
#        [-0.94483507],
#        [-0.92085448],
#        [-0.8968739 ],
#        [-0.8968739 ],
#        [-0.80095156],
#        [-0.7290098 ],
#        [-0.65706804],
#        [-0.68104863],
#        [-0.80095156],
#        [-0.87289331],
#        [-0.8968739 ],
#        [-1.01677683],
#        [-0.94483507],
#        [-1.01677683],
#        [-0.87289331],
#        [-0.51318453],
#        [-0.17745633],
#        [-0.03357282],
#        [ 0.06234952],
#        [ 0.18225245],
#        [ 0.68584475],
#        [ 0.94963119],
#        [ 1.06953411],
#        [ 1.35730114],
#        [ 1.14147587]])

# %%
# 2차원 -> 1차원 리스트에 담기
feed_list=[]
for i in feedScale :
    feed_list.append(i[0])

feed_list
# Out:
# [1.6690487510159508,
#  1.57312640900354,
#  1.5251652379973344,
#  1.5011846524942318,
#  1.5011846524942318,
#  1.7889516785314645,
#  1.7170099220221564,
#  1.5971069945066427,
#  1.6210875800097455,
#  1.7409905075252592,
#  1.6210875800097455,
#  0.9256506004197661,
#  1.4532234814880263,
#  1.3333205539725126,
#  1.7409905075252592,
#  1.8608934350407729,
#  1.9568157770531838,
#  2.028757533562492,
#  1.932835191550081,
#  1.7889516785314645,
#  1.4532234814880263,
#  1.3573011394756154,
#  1.285359382966307,
#  1.1414758699476908,
#  0.9016700149166634,
#  0.9016700149166634,
#  0.8057476729042524,
#  0.9016700149166634,
#  0.9736117714259716,
#  0.9256506004197661,
#  0.8776894294135607,
#  0.6378835743825333,
#  0.757786501898047,
#  0.39807771935150593,
#  0.44603889035771144,
#  0.5179806468670196,
#  0.3740971338484032,
#  0.30215537733909503,
#  0.1582718643204786,
#  0.014388351301862187,
#  0.06234952230806766,
#  -0.20143691822606244,
#  0.03836893680496492,
#  -0.15347574721985696,
#  -0.41726218775398705,
#  -0.29735926023847337,
#  -0.3453204312446788,
#  -0.513184529766398,
#  -0.5611457007726035,
#  -0.5371651152695007,
#  -0.44124277325708977,
#  -0.5371651152695007,
#  -0.5371651152695007,
#  -0.8249321413067335,
#  -0.5371651152695007,
#  -0.7290097992943226,
#  -0.9448350688222472,
#  -0.9927962398284527,
#  -0.8968738978160418,
#  -0.872893312312939,
#  -0.96881565432535,
#  -0.9927962398284527,
#  -1.0167768253315554,
#  -0.9208544833191444,
#  -0.8489127268098363,
#  -0.6570680427850144,
#  -0.7769709703005281,
#  -0.8249321413067335,
#  -0.9208544833191444,
#  -0.9448350688222472,
#  -0.9448350688222472,
#  -1.0647379963377608,
#  -1.1366797528470691,
#  -1.1846409238532745,
#  -1.1126991673439663,
#  -1.0887185818408636,
#  -0.9448350688222472,
#  -0.872893312312939,
#  -0.9448350688222472,
#  -0.7769709703005281,
#  -0.609106871778809,
#  -0.609106871778809,
#  -0.609106871778809,
#  -0.7050292137912199,
#  -0.7529903847974253,
#  -0.6330874572819116,
#  -0.6330874572819116,
#  -0.6330874572819116,
#  -0.609106871778809,
#  -0.5611457007726035,
#  -0.7050292137912199,
#  -0.8009515558036308,
#  -0.8968738978160418,
#  -0.8968738978160418,
#  -0.9448350688222472,
#  -0.9448350688222472,
#  -0.9208544833191444,
#  -0.8968738978160418,
#  -0.8968738978160418,
#  -0.8009515558036308,
#  -0.7290097992943226,
#  -0.6570680427850144,
#  -0.6810486282881171,
#  -0.8009515558036308,
#  -0.872893312312939,
#  -0.8968738978160418,
#  -1.0167768253315554,
#  -0.9448350688222472,
#  -1.0167768253315554,
#  -0.872893312312939,
#  -0.513184529766398,
#  -0.1774563327229597,
#  -0.03357281970434328,
#  0.06234952230806766,
#  0.18225244982358133,
#  0.6858447453887387,
#  0.9496311859228689,
#  1.0695341134383824,
#  1.3573011394756154,
#  1.1414758699476908]

# %%
feed_df
# Out:
#      Unnamed: 0        date  feedprice
# 0             0  2012-01-31        533
# 1             1  2012-02-29        529
# 2             2  2012-03-31        527
# 3             3  2012-04-30        526
# 4             4  2012-05-31        526
# ..          ...         ...        ...
# 115         115  2021-08-31        492
# 116         116  2021-09-30        503
# 117         117  2021-10-31        508
# 118         118  2021-11-30        520
# 119         119  2021-12-31        511
#
# [120 rows x 3 columns]

# %%
feed_df['feed_ss'] = feed_list
feed_list
# Out:
# [1.6690487510159508,
#  1.57312640900354,
#  1.5251652379973344,
#  1.5011846524942318,
#  1.5011846524942318,
#  1.7889516785314645,
#  1.7170099220221564,
#  1.5971069945066427,
#  1.6210875800097455,
#  1.7409905075252592,
#  1.6210875800097455,
#  0.9256506004197661,
#  1.4532234814880263,
#  1.3333205539725126,
#  1.7409905075252592,
#  1.8608934350407729,
#  1.9568157770531838,
#  2.028757533562492,
#  1.932835191550081,
#  1.7889516785314645,
#  1.4532234814880263,
#  1.3573011394756154,
#  1.285359382966307,
#  1.1414758699476908,
#  0.9016700149166634,
#  0.9016700149166634,
#  0.8057476729042524,
#  0.9016700149166634,
#  0.9736117714259716,
#  0.9256506004197661,
#  0.8776894294135607,
#  0.6378835743825333,
#  0.757786501898047,
#  0.39807771935150593,
#  0.44603889035771144,
#  0.5179806468670196,
#  0.3740971338484032,
#  0.30215537733909503,
#  0.1582718643204786,
#  0.014388351301862187,
#  0.06234952230806766,
#  -0.20143691822606244,
#  0.03836893680496492,
#  -0.15347574721985696,
#  -0.41726218775398705,
#  -0.29735926023847337,
#  -0.3453204312446788,
#  -0.513184529766398,
#  -0.5611457007726035,
#  -0.5371651152695007,
#  -0.44124277325708977,
#  -0.5371651152695007,
#  -0.5371651152695007,
#  -0.8249321413067335,
#  -0.5371651152695007,
#  -0.7290097992943226,
#  -0.9448350688222472,
#  -0.9927962398284527,
#  -0.8968738978160418,
#  -0.872893312312939,
#  -0.96881565432535,
#  -0.9927962398284527,
#  -1.0167768253315554,
#  -0.9208544833191444,
#  -0.8489127268098363,
#  -0.6570680427850144,
#  -0.7769709703005281,
#  -0.8249321413067335,
#  -0.9208544833191444,
#  -0.9448350688222472,
#  -0.9448350688222472,
#  -1.0647379963377608,
#  -1.1366797528470691,
#  -1.1846409238532745,
#  -1.1126991673439663,
#  -1.0887185818408636,
#  -0.9448350688222472,
#  -0.872893312312939,
#  -0.9448350688222472,
#  -0.7769709703005281,
#  -0.609106871778809,
#  -0.609106871778809,
#  -0.609106871778809,
#  -0.7050292137912199,
#  -0.7529903847974253,
#  -0.6330874572819116,
#  -0.6330874572819116,
#  -0.6330874572819116,
#  -0.609106871778809,
#  -0.5611457007726035,
#  -0.7050292137912199,
#  -0.8009515558036308,
#  -0.8968738978160418,
#  -0.8968738978160418,
#  -0.9448350688222472,
#  -0.9448350688222472,
#  -0.9208544833191444,
#  -0.8968738978160418,
#  -0.8968738978160418,
#  -0.8009515558036308,
#  -0.7290097992943226,
#  -0.6570680427850144,
#  -0.6810486282881171,
#  -0.8009515558036308,
#  -0.872893312312939,
#  -0.8968738978160418,
#  -1.0167768253315554,
#  -0.9448350688222472,
#  -1.0167768253315554,
#  -0.872893312312939,
#  -0.513184529766398,
#  -0.1774563327229597,
#  -0.03357281970434328,
#  0.06234952230806766,
#  0.18225244982358133,
#  0.6858447453887387,
#  0.9496311859228689,
#  1.0695341134383824,
#  1.3573011394756154,
#  1.1414758699476908]

# %%
feed_df
# Out:
#      Unnamed: 0        date  feedprice   feed_ss
# 0             0  2012-01-31        533  1.669049
# 1             1  2012-02-29        529  1.573126
# 2             2  2012-03-31        527  1.525165
# 3             3  2012-04-30        526  1.501185
# 4             4  2012-05-31        526  1.501185
# ..          ...         ...        ...       ...
# 115         115  2021-08-31        492  0.685845
# 116         116  2021-09-30        503  0.949631
# 117         117  2021-10-31        508  1.069534
# 118         118  2021-11-30        520  1.357301
# 119         119  2021-12-31        511  1.141476
#
# [120 rows x 4 columns]

# %%
# 월별 닭고기, 수입량 정규화 그래프

plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name

x = price_df['date']
y1 = price_df['price_ss']
y2 = feed_df['feed_ss']

fig, ax1 = plt.subplots()
ax1.set_title('월별 닭고기 가격,사료가격 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기 가격')
ax1.plot(x, y1, color='blue',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('사료가격')
ax2.plot(x, y2, color='red',label='사료가격')

plt.xticks(['2012-01-31', '2013-01-31', '2014-01-31','2015-01-31','2016-01-31','2017-01-31', '2018-01-31', '2019-01-31', '2020-01-31', '2021-01-31'])
fig.legend()
plt.show()
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 그룹별 정규화 그래프 [ 닭고기(red) / 병아리(원/수)(blue) ]
#
# ##### 그래프를 설명할 기준, 지수화 시키기 위한 기준
# - 정규화 된 [ 닭고기 평균 값 / 병아리(원/수) 평균 값 ] 구하기
# - 각 값들이 평균으로부터 떨어진 거리 (분산 or 표준편차) 구하기
# - 평균 - 평균 후 값들이 떨어진 거리들도 같이 계산하기
#
# -생각해볼 부분
# - 평균대비 해석해도 가능 꼭지점 기준으로 해도되고 그래프도 가능...
# - 파란거 평균 선 으로 해석 가능
# - 평균 대비 폭 >> 평균끼리 차이점 구가늬 플마값을 거리 절대값

# %%
# 그래프 편차에 맞춰 닭고기 가격, 수입량 기간 분리
price_group1 = price_df.iloc[:23,:]
price_group2 = price_df.iloc[24:83,:]
price_group3 = price_df.iloc[84:,:]


feed_group1 = feed_df.iloc[:23,:]
feed_group2 = feed_df.iloc[24:83,:]
feed_group3 = feed_df.iloc[84:,:]

# %% [markdown]
# ##### 그래프 시각화

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group1['date']
y1 = price_group1['price_ss']
y2 = feed_group1['feed_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 사료가격 그룹1 (2012-2013) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('사료가격')
ax2.plot(x, y2, color='blue',label='사료가격')

plt.xticks(['2012-01-31', '2012-04-30', '2012-07-31', '2012-10-31', '2013-01-31', '2013-04-30', '2013-07-31', '2013-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group2['date']
y1 = price_group2['price_ss']
y2 = feed_group2['feed_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 사료가격 그룹2 (2014-2018) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('사료가격')
ax2.plot(x, y2, color='blue',label='사료가격')

plt.xticks(['2014-01-31', '2014-04-30', '2014-07-31', '2014-10-31', '2015-01-31', '2015-04-30', '2015-07-31', '2015-10-31', '2016-01-31', '2016-04-30', '2016-07-31', '2016-10-31',
             '2017-01-31', '2017-04-30', '2017-07-31', '2017-10-31', '2018-01-31', '2018-04-30', '2018-07-31', '2018-10-31'])
fig.legend()
plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = font_name
matplotlib.rcParams['axes.unicode_minus'] = False 

x = price_group3['date']
y1 = price_group3['price_ss']
y2 = feed_group3['feed_ss']

fig, ax1 = plt.subplots()
ax1.set_title('닭고기, 사료가격 그룹3 (2019-2021) 정규화 그래프')
ax1.set_xlabel('시점')
ax1.set_ylabel('닭고기')
ax1.plot(x, y1, color='red',label='닭고기')

ax2 = ax1.twinx()
ax2.set_ylabel('사료가격')
ax2.plot(x, y2, color='blue',label='사료가격')

plt.xticks(['2019-01-31', '2019-04-30', '2019-07-31', '2019-10-31', '2020-01-31', '2020-04-30', '2020-07-31', '2020-10-31', '2021-01-31', '2021-04-30', '2021-07-31', '2021-10-31'])
fig.legend()
plt.show()

# %% [markdown]
# ##### 그룹별 정규화된 병아리(원/수), 닭고기 가격 값 평균 구하기

# %%
price_ss_mean1 = price_group1['price_ss'].mean()
feed_ss_mean1 = feed_group1['feed_ss'].mean()

print(price_ss_mean1, feed_ss_mean1)
# Out:
# 0.8236048204131915 1.6075333360297306

# %%
price_ss_mean2 = price_group2['price_ss'].mean()
feed_ss_mean2 = feed_group2['feed_ss'].mean()

print(price_ss_mean2, feed_ss_mean2)
# Out:
# -0.05724049804498116 0.2159851441425625

# %%
price_ss_mean3 = price_group3['price_ss'].mean()
feed_ss_mean3 = feed_group3['feed_ss'].mean()

print(price_ss_mean3, feed_ss_mean3)
# Out:
# -0.47074463000894234 -0.4525669386335549

# %% [markdown]
# ##### 그룹별 정규화된 수입량, 닭고기 가격 값 평균으로부터 떨어진 거리 구하기

# %%
price_group1['price_ss_mean'] = (price_group1['price_ss'] - price_ss_mean1).abs()
price_group1.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\3153625502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group1['price_ss_mean'] = (price_group1['price_ss'] - price_ss_mean1).abs()
#    Unnamed: 0        date  price  price_ss  price_ss_mean
# 0           0  2012-01-31   3202 -0.159385       0.982990
# 1           1  2012-02-29   3668  0.912513       0.088908
# 2           2  2012-03-31   4169  2.064919       1.241314
# 3           3  2012-04-30   3399  0.293756       0.529849
# 4           4  2012-05-31   3255 -0.037474       0.861079

# %%
feed_group1['feed_ss_mean'] = (feed_group1['feed_ss'] - feed_ss_mean1).abs()
feed_group1.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\3605899691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feed_group1['feed_ss_mean'] = (feed_group1['feed_ss'] - feed_ss_mean1).abs()
#    Unnamed: 0        date  feedprice   feed_ss  feed_ss_mean
# 0           0  2012-01-31        533  1.669049      0.061515
# 1           1  2012-02-29        529  1.573126      0.034407
# 2           2  2012-03-31        527  1.525165      0.082368
# 3           3  2012-04-30        526  1.501185      0.106349
# 4           4  2012-05-31        526  1.501185      0.106349

# %%
price_group2['price_ss_mean'] = (price_group2['price_ss'] - price_ss_mean2).abs()
price_group2.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\4256625362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group2['price_ss_mean'] = (price_group2['price_ss'] - price_ss_mean2).abs()
#     Unnamed: 0        date  price  price_ss  price_ss_mean
# 24          24  2014-01-31   3368  0.222450       0.279690
# 25          25  2014-02-28   3391  0.275354       0.332595
# 26          26  2014-03-31   3651  0.873409       0.930650
# 27          27  2014-04-30   3964  1.593376       1.650616
# 28          28  2014-05-31   3017 -0.584925       0.527684

# %%
feed_group2['feed_ss_mean'] = (feed_group2['feed_ss'] - feed_ss_mean1).abs()
feed_group2.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\1396631540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feed_group2['feed_ss_mean'] = (feed_group2['feed_ss'] - feed_ss_mean1).abs()
#     Unnamed: 0        date  feedprice   feed_ss  feed_ss_mean
# 24          24  2014-01-31        501  0.901670      0.705863
# 25          25  2014-02-28        501  0.901670      0.705863
# 26          26  2014-03-31        497  0.805748      0.801786
# 27          27  2014-04-30        501  0.901670      0.705863
# 28          28  2014-05-31        504  0.973612      0.633922

# %%
price_group3['price_ss_mean'] = (price_group3['price_ss'] - price_ss_mean3).abs()
price_group3.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\1996725595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_group3['price_ss_mean'] = (price_group3['price_ss'] - price_ss_mean3).abs()
#     Unnamed: 0        date  price  price_ss  price_ss_mean
# 84          84  2019-01-31   4281  2.322543       2.793287
# 85          85  2019-02-28   3384  0.259253       0.729998
# 86          86  2019-03-31   3397  0.289156       0.759900
# 87          87  2019-04-30   3166 -0.242193       0.228552
# 88          88  2019-05-31   2841 -0.989762       0.519017

# %%
feed_group3['feed_ss_mean'] = (feed_group3['feed_ss'] - feed_ss_mean1).abs()
feed_group3.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_27368\324021124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feed_group3['feed_ss_mean'] = (feed_group3['feed_ss'] - feed_ss_mean1).abs()
#     Unnamed: 0        date  feedprice   feed_ss  feed_ss_mean
# 84          84  2019-01-31        432 -0.752990      2.360524
# 85          85  2019-02-28        437 -0.633087      2.240621
# 86          86  2019-03-31        437 -0.633087      2.240621
# 87          87  2019-04-30        437 -0.633087      2.240621
# 88          88  2019-05-31        438 -0.609107      2.216640
