# %%
import pandas as pd

# %%
first_news = pd.read_csv('/localRepository/recipes_oraganization/meat-price-prediction/크롤링/2021년1분기뉴스.csv')
first_news
# Out:
#      Unnamed: 0                    날짜                                   기사제목  \
# 0             0   2021.03.10. 오후 8:54   유통기한 지난 닭고기 폐기 않고 치킨집·식당에 판 업체 6곳 적발
# 1             1  2021.03.04. 오전 11:15   계란·닭고기·대파 값 '껑충' 소비자물가 1%대 올렸다(종합2보)
# 2             2   2021.03.30. 오후 2:56      AI 대응 종계 입식 늘어나…"하반기 닭고기 공급과잉 우려"
# 3             3   2021.03.23. 오후 5:05         노브랜드버거, 대체육 너겟 품평회…"진짜 닭고기 같네"
# 4             4   2021.03.31. 오전 8:17  닭고기 없는 치킨너겟.. 노브랜드버거, 대체육 '노치킨 너겟' 출시
# ..          ...                   ...                                    ...
# 573         573   2021.01.06. 오후 2:14        [오늘의 유통 단신] 쿠팡, '알뜰한 멍냥상회' 운영 外
# 574         574   2021.01.01. 오전 5:46          자기계발·건강…e커머스, 새해 결심상품 할인 ‘풍성’
# 575         575   2021.01.01. 오전 5:46          자기계발·건강…e커머스, 새해 결심상품 할인 ‘풍성’
# 576         576   2021.01.06. 오전 9:53        쿠팡, '알뜰한 멍냥상회' 기획전 진행…최대 65% 할인
# 577         577   2021.01.06. 오후 2:14        [오늘의 유통 단신] 쿠팡, '알뜰한 멍냥상회' 운영 外
#
# ...
